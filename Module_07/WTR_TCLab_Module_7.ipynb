# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
from pytexit import py2tex
from IPython.display import Markdown
from gekko import GEKKO
import pandas as pd
from matplotlib import rcParams
import os
import sys
from copy import copy
from pytexit import py2tex


import sympy as sp
sp.init_printing()


# %matplotlib widget
#%matplotlib inline

# Look for custom python codes in the Radigan Engineering Vault...
sys.path.insert(1, 'C:\\\\RadiganVault\\\\Python')

import RadiganEngineeringDefaults as RE
from RadiganEngineering_Materials_Library import *
from RadiganEngineeringTorsionSpring import *
from RadiganEngineeringBellevilleSpring import *

# Use higher quality figures in PDF exports
#rcParams['figure.dpi']= 300
#rcParams['figure.figsize'] = [8, 6]
set_matplotlib_formats('png', 'pdf')

print(ALUMINUM_6061_T6.Specific_Heat)
# Out:
# 896 joule / kelvin / kilogram

# %%
# https://apmonitor.com/pdc/index.php/Main/TCLabSim
# https://apmonitor.com/pdc/index.php/Main/TCLabConvection

# Update model with natural convection estimation.

TCLab = GEKKO(remote=False)    # create GEKKO model for dx/dt

t_sim = 1500 * ureg.sec # Number of seconds to simulate
points_per_second = 1 # Only works if this is the same as the 'sampling frequency' in the cell below...

TCLab.time = np.linspace(0, t_sim.magnitude, (t_sim.magnitude * points_per_second) + 1) * ureg.sec # time points

# dt is in the units of ________.

# --> Inputs (7):
T_Ambient = Q_(23.0, ureg.degC)
HS_Mass  = 0.004 * ureg.kg 
HS_Cp    = 500.0 * (ureg.joule /  (ureg.kg    * ureg.kelvin)) # Heatsink Specific Heat
HS_Conv  = 5.0   * (ureg.watt) / ((ureg.m**2) * ureg.kelvin)  # Convection coefficient
# NOTE: This lesson changes the convection coefficient from 10 to 5 W/m^2-K, in order to make a better match when including the RADIATION TERM.
HS_Area  = 0.0012 * ureg.m**2                                 # Heatsink Surface Area

sigma    = 5.67e-8 # W/m2-K4
epsilon  = 0.9

# Starting temperature for the heatsink.
# Might be equal to 'T_Ambient' or something else.
HS_T_Start = T_Ambient
#HS_T_Start = Q_(23.0, ureg.degC)

# Curve defining the heater setting over the course of time.
HeaterValues = np.zeros(len(TCLab.time))
HeaterValues[15:300] = 20
HeaterValues[300:600] = 75
HeaterValues[600:900] = 0
HeaterValues[900:1200] = 50
#HeaterValues[15:800] = 50
#HeaterValues[0:9] = 50
Heater_Q  = TCLab.Param(HeaterValues)  # "Percentage of maximum value" of the heater

Heater_Coefficient = 0.01
GK_Heater_Coefficient       = TCLab.Param(Heater_Coefficient)  # ~= 0.01 Watts / % # This seems a little low, I would have expected more than 1 Watt at full power [100%] from the USB source.

# --> States (1): (Variables, with initial conditions)
#print('Heatsink Starting Temperature is {0}'.format(HS_T_Start.to('degC').magnitude))
GK_HS_Temp_C   = TCLab.Var(HS_T_Start.to('degC').magnitude) # GEKKO variable for the temperature of the heatsink

# --> Equations (1): 
GK_HS_Temp_K  = TCLab.Intermediate(GK_HS_Temp_C + 273.15) # Convert to Kelvin for the Radiation term
GK_Convection = TCLab.Intermediate(  (HS_Conv.to('watt/(m^2*K)').magnitude * HS_Area.to('m^2').magnitude) * (T_Ambient.to('kelvin').magnitude - GK_HS_Temp_K)  )
GK_Radiation  = TCLab.Intermediate(  sigma * epsilon * HS_Area.to('m^2').magnitude * (T_Ambient.to('kelvin').magnitude**4 - GK_HS_Temp_K**4)  )
GK_Loss       = TCLab.Intermediate(GK_Convection + GK_Radiation)
GK_Gain       = TCLab.Intermediate(GK_Heater_Coefficient * Heater_Q)


# GEKKO model Equation
TCLab.Equation(GK_HS_Temp_C.dt()  == ( GK_Convection + GK_Radiation + GK_Gain ) / 
                                     (HS_Mass.to('kg').magnitude * HS_Cp.to('joule/(kg*K)').magnitude) )



############### GEKKO SOLVER OPTIONS ######################
# solve ODEs and plot
# https://gekko.readthedocs.io/en/latest/imode.html
TCLab.options.IMODE = 4 # dynamic simulation

# Type: Integer, Input/Output
# Default Value: 0
# Description: Cold start model: 0=warm start, 1=cold start, 2=decompose problem
#TCLab.options.COLDSTART = 2

#TCLab.options.SOLVER = 1
#TCLab.options.MAX_ITER = 1000

TCLab.options.NODES = 3
TCLab.options.TIME_SHIFT=0

# Solve the dynamic system
TCLab.solve(disp=False)
############### GEKKO SOLVER OPTIONS ######################





#######################################################################################
####################################### SymPy #########################################
# SymPy equations for the partial derivitives
SP_h,SP_Area,SP_T_Ambient,SP_Temp_HS = sp.symbols(['h','A','T_A','T_HS']) # Convection symbols
spConvection                  = (SP_h * SP_Area) * (SP_T_Ambient - SP_Temp_HS)
#display('Convection Term:')
#display(spConvection)

SP_sigma, SP_epsilon            = sp.symbols(['sigma','epsilon'])
SP_Radiation                   = SP_sigma * SP_epsilon * SP_Area * (SP_T_Ambient**4 - SP_Temp_HS**4)
#display('Radiation Term:')
#display(SP_Radiation)

SP_Heater_Coefficient, SP_Heater_Q            = sp.symbols(['alpha','Q'])
SP_Gain                        = SP_Heater_Coefficient * SP_Heater_Q
#display('Heat Gain Term:')
#display(SP_Gain)


# Sympy Equation
SP_mass, SP_C_p, SP_dTdt  = sp.symbols(['m','C_p',r'\frac{dT}{dt}'])
SP_TCModel =  (spConvection + SP_Radiation + SP_Gain) / (SP_mass * SP_C_p)
#display('Model Equation Right-Hand-Side:')
#display(SP_TCModel)

# A SymPy 'Equation' includes what is on both the RIGHT and LEFT hand side of the '='
SP_TCLab_Equation = sp.Eq(SP_dTdt, SP_TCModel )
display('Full Model Equation:')
display(SP_TCLab_Equation)

# Sympy symbols for the linearized models.
SP_gamma,SP_beta = sp.symbols(['gamma','beta'])

display('"gamma" is the Model partial derivitive with respect to "SP_Temp_HS":')
gamma = sp.Eq(SP_gamma,sp.diff(SP_TCModel , SP_Temp_HS))
display(gamma)

# NOTE: The model is linearized in "Degrees Celsius", but 'gamma' is calculated in 'Kelvin'!
#Linearization_Temp = HS_T_Start
Linearization_Temp = T_Ambient
#Linearization_Temp = Q_(90.0, ureg.degC)

print('Given:')
print('   T_Ambient    = {0:.1f} | {1:.1f}'.format(T_Ambient.to('kelvin'), T_Ambient.to('degC')) )

display('If:')
print('   T_HS    = {0:.1f} | {1:.1f}'.format(Linearization_Temp.to('kelvin'), Linearization_Temp.to('degC')) )
print('   Area    = {0}'.format(HS_Area.to('m^2')))
print('   epsilon = {0}'.format(epsilon))
print('   sigma   = {0}'.format(sigma))
print('   h       = {0}'.format(HS_Conv.to('watt/(m^2*K)')))
print('   Cp      = {0}'.format(HS_Cp.to('joule/(kg*K)')))
print('   mass    = {0}'.format(HS_Mass.to('kg')))
display('Then:')
gamma_solved = (sp.sympify(gamma.subs(SP_Temp_HS , Linearization_Temp.to('kelvin').magnitude)
                                .subs(SP_Area, HS_Area.to('m^2').magnitude)
                                .subs(SP_epsilon, epsilon)
                                .subs(SP_sigma, sigma)
                                .subs(SP_h, HS_Conv.to('watt/(m^2*K)').magnitude)
                                .subs(SP_C_p, HS_Cp.to('joule/(kg*K)').magnitude)
                                .subs(SP_mass,   HS_Mass.to('kg').magnitude  )
                                .evalf(4) ))
display(gamma_solved)

print('\n')
display('In Python:')
print(float(gamma_solved.rhs))

print('\n\n')
display('"Beta" is the Model partial derivitive with respect to "SP_Heater_Q":')
beta = sp.Eq(SP_beta, sp.diff(SP_TCModel , SP_Heater_Q) )
display(beta)
display('If:')
print('   mass     = {0}'.format(HS_Mass.to('kg')))
print('   C_p      = {0}'.format(HS_Cp.to('joule/(kg*K)')))
print('   alpha    = {0}'.format(Heater_Coefficient))
display('Then:')
beta_solved = (sp.sympify(beta.subs(SP_mass,   HS_Mass.to('kg').magnitude  )
                              .subs(SP_Heater_Coefficient,   Heater_Coefficient  )
                              .subs(SP_C_p,   HS_Cp.to('joule/(kg*K)').magnitude  )
                              .evalf(4) ))

display(beta_solved)
display('In Python:')
print(float(beta_solved.rhs))
####################################### SymPy #########################################
#######################################################################################


##################################################################################################
################################## LINEARIZED GEKKO MODEL ########################################

#ANS_gamma = -U*A/(m*Cp) - 4*eps*sigma*A*TaK**3/(m*Cp)
#ANS_beta = alpha/(m*Cp)

TaK = Linearization_Temp.to('kelvin').magnitude
ANSWER_beta = Heater_Coefficient /(HS_Mass.to('kg').magnitude * HS_Cp.to('joule/(kg*K)').magnitude)

ANSWER_gamma = -HS_Conv.to('watt/(m^2*K)').magnitude * HS_Area.to('m^2').magnitude / (HS_Mass.to('kg').magnitude * HS_Cp.to('joule/(kg*K)').magnitude)  - 4*epsilon*sigma*HS_Area.to('m^2').magnitude*TaK**3  /  ( HS_Mass.to('kg').magnitude *  HS_Cp.to('joule/(kg*K)').magnitude )

print('ANSWER_gamma = {}'.format(ANSWER_gamma))
print('ANSWER_beta  = {}'.format(ANSWER_beta))

TCLab_Linear = GEKKO(remote=False)    # create GEKKO model for dx/dt
TCLab_Linear.time = np.linspace(0, t_sim.magnitude, (t_sim.magnitude * points_per_second) + 1) * ureg.sec # time points

GKL_HS_Temp_C   = TCLab_Linear.Var(HS_T_Start.to('degC').magnitude) # GEKKO variable for the temperature of the heatsink
GKL_Heater_Q    = TCLab_Linear.Param(HeaterValues)  # "Percentage of maximum value" of the heater

GKL_Heater_Linearization_Point      = 0.0
# NOTE: The model is linearized in "Degrees Celsius", but 'gamma' is calculated in 'Kelvin'!
GKL_Temperature_Linearization_Point = Linearization_Temp.to('degC').magnitude

GKL_gamma       = TCLab_Linear.Param(float(gamma_solved.rhs))
GKL_Beta        = TCLab_Linear.Param(float(beta_solved.rhs))


# The are constant values that are preliminary computations for the 'alpha' term in the model linearization below.
# The model can be 'linearized' at any point to minimize the errors at that point
GKL_HS_Temp_K  = GKL_Temperature_Linearization_Point + 273.15 # Convert to Kelvin for the Radiation term
GKL_Convection = (HS_Conv.to('watt/(m^2*K)').magnitude * HS_Area.to('m^2').magnitude) * (T_Ambient.to('kelvin').magnitude - GKL_HS_Temp_K)
GKL_Radiation  = sigma * epsilon * HS_Area.to('m^2').magnitude * (T_Ambient.to('kelvin').magnitude**4 - GKL_HS_Temp_K**4)
GKL_Gain       = Heater_Coefficient * GKL_Heater_Linearization_Point

# This 'alpha' term is f(x0,u0) --> Which is the non-linear function evaluated at the x0, u0 linearization points
GKL_alpha = ( GKL_Convection + GKL_Radiation + GKL_Gain ) / (HS_Mass.to('kg').magnitude * HS_Cp.to('joule/(kg*K)').magnitude)


# This is the 'Linearized' model equation.
TCLab_Linear.Equation(GKL_HS_Temp_C.dt()  == GKL_alpha + GKL_gamma * (GKL_HS_Temp_C - GKL_Temperature_Linearization_Point) + 
                                                         GKL_Beta  * (GKL_Heater_Q  - GKL_Heater_Linearization_Point) )

############### GEKKO SOLVER OPTIONS ######################
# solve ODEs and plot
# https://gekko.readthedocs.io/en/latest/imode.html
TCLab_Linear.options.IMODE = 4 # dynamic simulation

# Type: Integer, Input/Output
# Default Value: 0
# Description: Cold start model: 0=warm start, 1=cold start, 2=decompose problem
#TCLab_Linear.options.COLDSTART = 2

#TCLab_Linear.options.SOLVER = 1
#TCLab_Linear.options.MAX_ITER = 1000

TCLab_Linear.options.NODES = 3
TCLab_Linear.options.TIME_SHIFT=0

# Solve the dynamic system
TCLab_Linear.solve(disp=False)
############### GEKKO SOLVER OPTIONS ######################

################################## LINEARIZED GEKKO MODEL ########################################
##################################################################################################







#######################################################################################
########################### PLOT SIMULATION RESULTS ###################################
fig = plt.figure(figsize=(12,4))
plt_ax = plt.subplot(1,2,1)
#plt_ax = plt.axes(label='TCLab')
#plt_ax.set_ylim(20,65)
plt_ax.set_ylim(T_Ambient.to('degC').magnitude - 5.0, max(GK_HS_Temp_C.value) + 5.0)


print('Max Predicted Temperature = {0:.2f}'.format(max(GK_HS_Temp_C.value)))

# Plot the heatsink temperature as a function of time NON-LINEAR MODEL! (And Heater input curve...)
plt_ax.plot(TCLab.time,       GK_HS_Temp_C, color = 'blue', linestyle = '-', marker='',linewidth=1,label=r'$\alpha$ = {0}'.format(GK_Heater_Coefficient.value[0]))

# Plot the heatsink temperature from the LINEAR MODEL as a function of time. (And Heater input curve...)
plt_ax.plot(TCLab_Linear.time,GKL_HS_Temp_C, color = 'blue', linestyle = ':', marker='',linewidth=1,label=r'NL $\alpha$ = {0}'.format(GK_Heater_Coefficient.value[0]))


######################################################################################
# Create the 'dummy' plot with NaN's that will be replaced with measured data below.
T1 = np.empty(len(TCLab.time))
T1[:] = np.nan
T1_time = np.empty(len(TCLab.time))
T1_time[:] = np.nan
MeasuredDataPlot, = plt_ax.plot(T1_time,T1,'r.', label='Measured')
######################################################################################

plt.grid(True)
plt.title('TC Lab Thermal Simulation')
plt.xlabel('Time (sec)')
plt.ylabel('Temperature (degC)')
plt.legend()
plt.show()

# Make a second plot that shows the heat Gain & Loss terms
plt_ax2 = plt.subplot(1,2,2)
plt_ax2.plot(TCLab.time,GK_Convection, color = 'blue',   linestyle = '-', marker='',linewidth=1,label='Convection')
plt_ax2.plot(TCLab.time,GK_Radiation,  color = 'orange', linestyle = '-', marker='',linewidth=1,label='Radiation')
plt_ax2.plot(TCLab.time,GK_Loss,       color = 'green',  linestyle = '-', marker='',linewidth=1,label='Total Loss')
plt_ax2.plot(TCLab.time,GK_Gain,       color = 'red',    linestyle = '-', marker='',linewidth=1,label='Heater Gain')
plt.title('TC Lab Heat Gain & Loss Terms')
plt.xlabel('Time (sec)')
plt.ylabel('Energy (Watts)')
plt.legend()
plt.grid(True)

# instantiate a second axes that shares the same x-axis and plot the Heater Input
Q_ax = plt_ax2.twinx()  
Q_ax.plot(TCLab.time,Heater_Q, color = 'gray', linestyle = ':', marker='',linewidth=2,label='Heater')
Q_ax.set_ylim(-5,105)
plt.ylabel('Heater Percentage')
plt.legend(loc = 'lower right')

plt.subplots_adjust(wspace = 0.4 )

########################### PLOT SIMULATION RESULTS ###################################
#######################################################################################
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gekko\gk_write_files.py:144: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   csv_data = np.hstack(('time',np.array(self.time).flatten().astype(object)))
# 'Full Model Equation:'
#                       ⎛   4       4⎞
#                 A⋅ε⋅σ⋅⎝T_A  - T_HS ⎠ + A⋅h⋅(T_A - T_HS) + Q⋅α
# \frac{dT}{dt} = ─────────────────────────────────────────────
#                                      Cₚ⋅m
# '"gamma" is the Model partial derivitive with respect to "SP_Temp_HS":'
#               3
#     - 4⋅A⋅T_HS ⋅ε⋅σ - A⋅h
# γ = ─────────────────────
#              Cₚ⋅m
# Given:
#    T_Ambient    = 296.1 kelvin | 23.0 degree_Celsius
# 'If:'
#    T_HS    = 296.1 kelvin | 23.0 degree_Celsius
#    Area    = 0.0012 meter ** 2
#    epsilon = 0.9
#    sigma   = 5.67e-08
#    h       = 5.0 watt / kelvin / meter ** 2
#    Cp      = 500.0 joule / kelvin / kilogram
#    mass    = 0.004 kilogram
# 'Then:'
# γ = -0.006181
# 'In Python:'
# -0.006181061267852783
# '"Beta" is the Model partial derivitive with respect to "SP_Heater_Q":'
#      α
# β = ────
#     Cₚ⋅m
# 'If:'
#    mass     = 0.004 kilogram
#    C_p      = 500.0 joule / kelvin / kilogram
#    alpha    = 0.01
# 'Then:'
# β = 0.005
# 'In Python:'
# 0.004999995231628418
# ANSWER_gamma = -0.006181061174034302
# ANSWER_beta  = 0.005
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Max Predicted Temperature = 71.85

# %%
# Actual measured data
import tclab
import time


if (1):
    lab = tclab.TCLab()
    
    # Use the array defined above to set the heater.
    lab.Q1(HeaterValues[0])
    Start_Time = time.time()

    T1[:] = np.nan       # Reset the measured temperatures to NaN's
    T1_time[:] = np.nan
    DTime = np.empty_like(HeaterValues)
    ElapsedTime = np.empty_like(HeaterValues)
    
    for i in range(len(TCLab.time)):
        time.sleep(1)
        lab.Q1(HeaterValues[i])
        T1[i] = lab.T1
        T1_time[i] = i
        DTime[i] = time.time()
        ElapsedTime[i] = DTime[i] - Start_Time
        
        print('N = {3}, Time = {4:.1f}, T1 = {0}, T2 = {1}, Heater Set to {2}'.format(lab.T1, lab.T2, HeaterValues[i], i, ElapsedTime[i]))
        MeasuredDataPlot.set_ydata(np.array(T1))
        #MeasuredDataPlot.set_xdata(np.array(T1_time))
        MeasuredDataPlot.set_xdata(ElapsedTime)
        plt_ax.set_title("{0} of {1} Points Measured".format(i+1,t_sim))
        fig.canvas.draw()
        fig.canvas.flush_events()
        plt.show()
    
    PD_MeasuredData = pd.DataFrame(data = {'DTime':  DTime,
                                        'ElapsedTime': ElapsedTime,
                                        'T1': T1,
                                        'T1_time': T1_time,
                                        'HeaterValues': HeaterValues
                                       })
    PD_MeasuredData.to_csv('TCLab_Measured_Data.csv')
    lab.close()
    plt.show()
# Out:
# TCLab version 0.4.9
# Arduino Leonardo connected on port COM3 at 115200 baud.
# TCLab Firmware 1.4.3 Arduino Leonardo/Micro.
# N = 0, Time = 1.1, T1 = 23.81, T2 = 23.48, Heater Set to 0.0
# N = 1, Time = 2.5, T1 = 23.81, T2 = 23.81, Heater Set to 0.0
# N = 2, Time = 3.8, T1 = 23.81, T2 = 23.81, Heater Set to 0.0
# N = 3, Time = 5.1, T1 = 23.81, T2 = 23.81, Heater Set to 0.0
# N = 4, Time = 6.4, T1 = 23.81, T2 = 23.48, Heater Set to 0.0
# N = 5, Time = 7.8, T1 = 23.81, T2 = 23.48, Heater Set to 0.0
# N = 6, Time = 9.1, T1 = 23.81, T2 = 23.81, Heater Set to 0.0
# N = 7, Time = 10.4, T1 = 24.13, T2 = 23.81, Heater Set to 0.0
# N = 8, Time = 11.7, T1 = 23.81, T2 = 23.81, Heater Set to 0.0
# N = 9, Time = 13.1, T1 = 23.81, T2 = 23.81, Heater Set to 0.0
# N = 10, Time = 14.4, T1 = 24.13, T2 = 23.48, Heater Set to 0.0
# N = 11, Time = 15.7, T1 = 23.81, T2 = 23.81, Heater Set to 0.0
# N = 12, Time = 17.0, T1 = 23.81, T2 = 23.81, Heater Set to 0.0
# N = 13, Time = 18.4, T1 = 24.13, T2 = 23.81, Heater Set to 0.0
# N = 14, Time = 19.7, T1 = 24.13, T2 = 23.81, Heater Set to 0.0
# N = 15, Time = 21.1, T1 = 24.13, T2 = 23.81, Heater Set to 20.0
# N = 16, Time = 22.4, T1 = 24.13, T2 = 23.48, Heater Set to 20.0
# N = 17, Time = 23.8, T1 = 24.13, T2 = 23.81, Heater Set to 20.0
# N = 18, Time = 25.1, T1 = 24.13, T2 = 23.81, Heater Set to 20.0
# N = 19, Time = 26.5, T1 = 24.13, T2 = 23.81, Heater Set to 20.0
# N = 20, Time = 27.8, T1 = 24.13, T2 = 23.81, Heater Set to 20.0
# N = 21, Time = 29.2, T1 = 24.13, T2 = 23.81, Heater Set to 20.0
# N = 22, Time = 30.6, T1 = 24.13, T2 = 23.81, Heater Set to 20.0
# N = 23, Time = 31.9, T1 = 24.13, T2 = 23.81, Heater Set to 20.0
# N = 24, Time = 33.3, T1 = 24.13, T2 = 23.81, Heater Set to 20.0
# N = 25, Time = 34.6, T1 = 24.13, T2 = 23.81, Heater Set to 20.0
# N = 26, Time = 36.0, T1 = 24.13, T2 = 23.81, Heater Set to 20.0
# N = 27, Time = 37.4, T1 = 24.13, T2 = 23.81, Heater Set to 20.0
# N = 28, Time = 38.7, T1 = 24.45, T2 = 23.81, Heater Set to 20.0
# N = 29, Time = 40.1, T1 = 24.45, T2 = 23.81, Heater Set to 20.0
# N = 30, Time = 41.5, T1 = 24.45, T2 = 23.81, Heater Set to 20.0
# N = 31, Time = 42.8, T1 = 24.45, T2 = 23.81, Heater Set to 20.0
# N = 32, Time = 44.2, T1 = 24.45, T2 = 23.81, Heater Set to 20.0
# N = 33, Time = 45.5, T1 = 24.77, T2 = 23.81, Heater Set to 20.0
# N = 34, Time = 46.9, T1 = 24.77, T2 = 23.81, Heater Set to 20.0
# N = 35, Time = 48.2, T1 = 24.77, T2 = 23.81, Heater Set to 20.0
# N = 36, Time = 49.6, T1 = 24.77, T2 = 23.81, Heater Set to 20.0
# N = 37, Time = 50.9, T1 = 24.77, T2 = 23.81, Heater Set to 20.0
# N = 38, Time = 52.3, T1 = 25.1, T2 = 23.81, Heater Set to 20.0
# N = 39, Time = 53.7, T1 = 25.1, T2 = 23.81, Heater Set to 20.0
# N = 40, Time = 55.0, T1 = 25.1, T2 = 23.81, Heater Set to 20.0
# N = 41, Time = 56.4, T1 = 25.1, T2 = 23.81, Heater Set to 20.0
# N = 42, Time = 57.7, T1 = 25.42, T2 = 23.81, Heater Set to 20.0
# N = 43, Time = 59.1, T1 = 25.42, T2 = 23.81, Heater Set to 20.0
# N = 44, Time = 60.4, T1 = 25.42, T2 = 23.81, Heater Set to 20.0
# N = 45, Time = 61.8, T1 = 25.42, T2 = 23.81, Heater Set to 20.0
# N = 46, Time = 63.1, T1 = 25.74, T2 = 23.81, Heater Set to 20.0
# N = 47, Time = 64.5, T1 = 25.74, T2 = 23.81, Heater Set to 20.0
# N = 48, Time = 65.8, T1 = 25.74, T2 = 23.81, Heater Set to 20.0
# N = 49, Time = 67.2, T1 = 26.06, T2 = 23.81, Heater Set to 20.0
# N = 50, Time = 68.5, T1 = 26.06, T2 = 23.81, Heater Set to 20.0
# N = 51, Time = 69.9, T1 = 26.06, T2 = 23.81, Heater Set to 20.0
# N = 52, Time = 71.3, T1 = 26.06, T2 = 23.81, Heater Set to 20.0
# N = 53, Time = 72.6, T1 = 26.06, T2 = 24.13, Heater Set to 20.0
# N = 54, Time = 73.9, T1 = 26.39, T2 = 24.13, Heater Set to 20.0
# N = 55, Time = 75.3, T1 = 26.39, T2 = 24.13, Heater Set to 20.0
# N = 56, Time = 76.7, T1 = 26.39, T2 = 24.13, Heater Set to 20.0
# N = 57, Time = 78.0, T1 = 26.71, T2 = 23.81, Heater Set to 20.0
# N = 58, Time = 79.4, T1 = 26.71, T2 = 24.13, Heater Set to 20.0
# N = 59, Time = 80.7, T1 = 26.71, T2 = 24.13, Heater Set to 20.0
# N = 60, Time = 82.1, T1 = 26.71, T2 = 24.13, Heater Set to 20.0
# N = 61, Time = 83.4, T1 = 27.03, T2 = 24.13, Heater Set to 20.0
# N = 62, Time = 84.8, T1 = 27.03, T2 = 24.13, Heater Set to 20.0
# N = 63, Time = 86.2, T1 = 27.03, T2 = 24.13, Heater Set to 20.0
# N = 64, Time = 87.5, T1 = 27.35, T2 = 24.13, Heater Set to 20.0
# N = 65, Time = 88.8, T1 = 27.35, T2 = 24.13, Heater Set to 20.0
# N = 66, Time = 90.2, T1 = 27.35, T2 = 24.13, Heater Set to 20.0
# N = 67, Time = 91.5, T1 = 27.35, T2 = 24.13, Heater Set to 20.0
# N = 68, Time = 92.9, T1 = 27.35, T2 = 24.13, Heater Set to 20.0
# N = 69, Time = 94.3, T1 = 27.03, T2 = 24.45, Heater Set to 20.0
# N = 70, Time = 95.6, T1 = 27.67, T2 = 24.45, Heater Set to 20.0
# N = 71, Time = 97.0, T1 = 27.67, T2 = 24.13, Heater Set to 20.0
# N = 72, Time = 98.3, T1 = 27.67, T2 = 24.13, Heater Set to 20.0
# N = 73, Time = 99.7, T1 = 28.0, T2 = 24.13, Heater Set to 20.0
# N = 74, Time = 101.0, T1 = 28.0, T2 = 24.45, Heater Set to 20.0
# N = 75, Time = 102.4, T1 = 28.0, T2 = 24.45, Heater Set to 20.0
# N = 76, Time = 103.7, T1 = 28.32, T2 = 24.13, Heater Set to 20.0
# N = 77, Time = 105.1, T1 = 28.0, T2 = 24.45, Heater Set to 20.0
# N = 78, Time = 106.4, T1 = 28.32, T2 = 24.45, Heater Set to 20.0
# N = 79, Time = 107.8, T1 = 28.64, T2 = 24.45, Heater Set to 20.0
# N = 80, Time = 109.2, T1 = 28.64, T2 = 24.45, Heater Set to 20.0
# N = 81, Time = 110.5, T1 = 28.64, T2 = 24.45, Heater Set to 20.0
# N = 82, Time = 111.9, T1 = 28.64, T2 = 24.45, Heater Set to 20.0
# N = 83, Time = 113.2, T1 = 28.64, T2 = 24.45, Heater Set to 20.0
# N = 84, Time = 114.6, T1 = 28.64, T2 = 24.45, Heater Set to 20.0
# N = 85, Time = 115.9, T1 = 28.96, T2 = 24.45, Heater Set to 20.0
# N = 86, Time = 117.3, T1 = 28.96, T2 = 24.45, Heater Set to 20.0
# N = 87, Time = 118.7, T1 = 28.96, T2 = 24.45, Heater Set to 20.0
# N = 88, Time = 120.0, T1 = 29.29, T2 = 24.45, Heater Set to 20.0
# N = 89, Time = 121.4, T1 = 29.29, T2 = 24.45, Heater Set to 20.0
# N = 90, Time = 122.8, T1 = 29.29, T2 = 24.77, Heater Set to 20.0
# N = 91, Time = 124.1, T1 = 29.29, T2 = 24.77, Heater Set to 20.0
# N = 92, Time = 125.5, T1 = 29.29, T2 = 24.77, Heater Set to 20.0
# N = 93, Time = 126.9, T1 = 29.29, T2 = 24.77, Heater Set to 20.0
# N = 94, Time = 128.2, T1 = 29.61, T2 = 24.77, Heater Set to 20.0
# N = 95, Time = 129.6, T1 = 29.61, T2 = 24.77, Heater Set to 20.0
# N = 96, Time = 131.0, T1 = 29.61, T2 = 24.77, Heater Set to 20.0
# N = 97, Time = 132.3, T1 = 29.61, T2 = 24.77, Heater Set to 20.0
# N = 98, Time = 133.7, T1 = 29.93, T2 = 24.77, Heater Set to 20.0
# N = 99, Time = 135.1, T1 = 29.93, T2 = 24.77, Heater Set to 20.0
# N = 100, Time = 136.4, T1 = 29.93, T2 = 25.1, Heater Set to 20.0
# N = 101, Time = 137.8, T1 = 29.93, T2 = 24.77, Heater Set to 20.0
# N = 102, Time = 139.1, T1 = 29.93, T2 = 25.1, Heater Set to 20.0
# N = 103, Time = 140.5, T1 = 30.25, T2 = 24.77, Heater Set to 20.0
# N = 104, Time = 141.9, T1 = 30.25, T2 = 25.1, Heater Set to 20.0
# N = 105, Time = 143.2, T1 = 30.25, T2 = 25.1, Heater Set to 20.0
# N = 106, Time = 144.6, T1 = 30.25, T2 = 25.1, Heater Set to 20.0
# N = 107, Time = 145.9, T1 = 30.57, T2 = 25.1, Heater Set to 20.0
# N = 108, Time = 147.3, T1 = 30.25, T2 = 25.1, Heater Set to 20.0
# N = 109, Time = 148.7, T1 = 30.57, T2 = 25.1, Heater Set to 20.0
# N = 110, Time = 150.0, T1 = 30.57, T2 = 25.1, Heater Set to 20.0
# N = 111, Time = 151.4, T1 = 30.57, T2 = 25.1, Heater Set to 20.0
# N = 112, Time = 152.8, T1 = 30.9, T2 = 25.1, Heater Set to 20.0
# N = 113, Time = 154.1, T1 = 30.9, T2 = 25.1, Heater Set to 20.0
# N = 114, Time = 155.5, T1 = 30.9, T2 = 25.1, Heater Set to 20.0
# N = 115, Time = 156.9, T1 = 30.9, T2 = 25.1, Heater Set to 20.0
# N = 116, Time = 158.2, T1 = 30.9, T2 = 25.1, Heater Set to 20.0
# N = 117, Time = 159.6, T1 = 31.22, T2 = 25.42, Heater Set to 20.0
# N = 118, Time = 161.0, T1 = 31.22, T2 = 25.42, Heater Set to 20.0
# N = 119, Time = 162.3, T1 = 31.22, T2 = 25.42, Heater Set to 20.0
# N = 120, Time = 163.7, T1 = 31.22, T2 = 25.42, Heater Set to 20.0
# N = 121, Time = 165.1, T1 = 31.22, T2 = 25.42, Heater Set to 20.0
# N = 122, Time = 166.5, T1 = 31.54, T2 = 25.42, Heater Set to 20.0
# N = 123, Time = 167.8, T1 = 31.54, T2 = 25.42, Heater Set to 20.0
# N = 124, Time = 169.2, T1 = 31.54, T2 = 25.42, Heater Set to 20.0
# N = 125, Time = 170.5, T1 = 31.54, T2 = 25.42, Heater Set to 20.0
# N = 126, Time = 171.9, T1 = 31.54, T2 = 25.74, Heater Set to 20.0
# N = 127, Time = 173.3, T1 = 31.86, T2 = 25.74, Heater Set to 20.0
# N = 128, Time = 174.6, T1 = 31.86, T2 = 25.74, Heater Set to 20.0
# N = 129, Time = 176.0, T1 = 31.86, T2 = 25.74, Heater Set to 20.0
# N = 130, Time = 177.3, T1 = 31.86, T2 = 25.74, Heater Set to 20.0
# N = 131, Time = 178.7, T1 = 31.86, T2 = 25.74, Heater Set to 20.0
# N = 132, Time = 180.1, T1 = 31.86, T2 = 25.74, Heater Set to 20.0
# N = 133, Time = 181.4, T1 = 32.19, T2 = 25.74, Heater Set to 20.0
# N = 134, Time = 182.8, T1 = 32.19, T2 = 25.42, Heater Set to 20.0
# N = 135, Time = 184.2, T1 = 32.19, T2 = 25.74, Heater Set to 20.0
# N = 136, Time = 185.6, T1 = 32.19, T2 = 25.74, Heater Set to 20.0
# N = 137, Time = 186.9, T1 = 32.19, T2 = 25.74, Heater Set to 20.0
# N = 138, Time = 188.3, T1 = 32.19, T2 = 25.74, Heater Set to 20.0
# N = 139, Time = 189.6, T1 = 32.51, T2 = 25.42, Heater Set to 20.0
# N = 140, Time = 191.0, T1 = 32.51, T2 = 25.74, Heater Set to 20.0
# N = 141, Time = 192.3, T1 = 32.51, T2 = 26.06, Heater Set to 20.0
# N = 142, Time = 193.7, T1 = 32.51, T2 = 25.74, Heater Set to 20.0
# N = 143, Time = 195.0, T1 = 32.51, T2 = 26.06, Heater Set to 20.0
# N = 144, Time = 196.4, T1 = 32.51, T2 = 26.06, Heater Set to 20.0
# N = 145, Time = 197.7, T1 = 32.51, T2 = 26.06, Heater Set to 20.0
# N = 146, Time = 199.1, T1 = 32.51, T2 = 26.06, Heater Set to 20.0
# N = 147, Time = 200.5, T1 = 32.83, T2 = 26.06, Heater Set to 20.0
# N = 148, Time = 201.8, T1 = 32.83, T2 = 26.06, Heater Set to 20.0
# N = 149, Time = 203.2, T1 = 32.83, T2 = 26.06, Heater Set to 20.0
# N = 150, Time = 204.6, T1 = 32.83, T2 = 26.06, Heater Set to 20.0
# N = 151, Time = 205.9, T1 = 32.83, T2 = 26.39, Heater Set to 20.0
# N = 152, Time = 207.3, T1 = 32.83, T2 = 26.06, Heater Set to 20.0
# N = 153, Time = 208.7, T1 = 32.83, T2 = 26.39, Heater Set to 20.0
# N = 154, Time = 210.0, T1 = 33.15, T2 = 26.39, Heater Set to 20.0
# N = 155, Time = 211.3, T1 = 33.15, T2 = 26.06, Heater Set to 20.0
# N = 156, Time = 212.7, T1 = 33.15, T2 = 26.39, Heater Set to 20.0
# N = 157, Time = 214.1, T1 = 33.15, T2 = 26.39, Heater Set to 20.0
# N = 158, Time = 215.4, T1 = 33.15, T2 = 26.39, Heater Set to 20.0
# N = 159, Time = 216.8, T1 = 33.48, T2 = 26.39, Heater Set to 20.0
# N = 160, Time = 218.2, T1 = 33.15, T2 = 26.39, Heater Set to 20.0
# N = 161, Time = 219.5, T1 = 33.48, T2 = 26.39, Heater Set to 20.0
# N = 162, Time = 220.9, T1 = 33.48, T2 = 26.39, Heater Set to 20.0
# N = 163, Time = 222.3, T1 = 33.48, T2 = 26.39, Heater Set to 20.0
# N = 164, Time = 223.6, T1 = 33.48, T2 = 26.39, Heater Set to 20.0
# N = 165, Time = 225.0, T1 = 33.48, T2 = 26.71, Heater Set to 20.0
# N = 166, Time = 226.3, T1 = 33.48, T2 = 26.71, Heater Set to 20.0
# N = 167, Time = 227.7, T1 = 33.48, T2 = 26.39, Heater Set to 20.0
# N = 168, Time = 229.0, T1 = 33.48, T2 = 26.71, Heater Set to 20.0
# N = 169, Time = 230.4, T1 = 33.8, T2 = 26.71, Heater Set to 20.0
# N = 170, Time = 231.8, T1 = 33.8, T2 = 26.71, Heater Set to 20.0
# N = 171, Time = 233.2, T1 = 33.8, T2 = 26.71, Heater Set to 20.0
# N = 172, Time = 234.5, T1 = 33.8, T2 = 26.71, Heater Set to 20.0
# N = 173, Time = 235.9, T1 = 33.8, T2 = 26.71, Heater Set to 20.0
# N = 174, Time = 237.2, T1 = 33.8, T2 = 26.71, Heater Set to 20.0
# N = 175, Time = 238.6, T1 = 33.8, T2 = 26.71, Heater Set to 20.0
# N = 176, Time = 240.0, T1 = 33.8, T2 = 27.03, Heater Set to 20.0
# N = 177, Time = 241.3, T1 = 34.12, T2 = 27.03, Heater Set to 20.0
# N = 178, Time = 242.7, T1 = 34.12, T2 = 27.03, Heater Set to 20.0
# N = 179, Time = 244.0, T1 = 34.12, T2 = 27.03, Heater Set to 20.0
# N = 180, Time = 245.4, T1 = 34.12, T2 = 27.03, Heater Set to 20.0
# N = 181, Time = 246.8, T1 = 34.12, T2 = 27.03, Heater Set to 20.0
# N = 182, Time = 248.1, T1 = 34.12, T2 = 27.03, Heater Set to 20.0
# N = 183, Time = 249.5, T1 = 34.12, T2 = 27.03, Heater Set to 20.0
# N = 184, Time = 250.9, T1 = 34.12, T2 = 27.03, Heater Set to 20.0
# N = 185, Time = 252.2, T1 = 34.44, T2 = 27.03, Heater Set to 20.0
# N = 186, Time = 253.6, T1 = 34.44, T2 = 27.03, Heater Set to 20.0
# N = 187, Time = 254.9, T1 = 34.44, T2 = 27.03, Heater Set to 20.0
# N = 188, Time = 256.3, T1 = 34.44, T2 = 27.03, Heater Set to 20.0
# N = 189, Time = 257.7, T1 = 34.44, T2 = 27.35, Heater Set to 20.0
# N = 190, Time = 259.0, T1 = 34.44, T2 = 27.03, Heater Set to 20.0
# N = 191, Time = 260.4, T1 = 34.44, T2 = 27.35, Heater Set to 20.0
# N = 192, Time = 261.7, T1 = 34.44, T2 = 27.35, Heater Set to 20.0
# N = 193, Time = 263.1, T1 = 34.44, T2 = 27.35, Heater Set to 20.0
# N = 194, Time = 264.5, T1 = 34.76, T2 = 27.35, Heater Set to 20.0
# N = 195, Time = 265.8, T1 = 34.76, T2 = 27.35, Heater Set to 20.0
# N = 196, Time = 267.2, T1 = 34.76, T2 = 27.35, Heater Set to 20.0
# N = 197, Time = 268.5, T1 = 34.12, T2 = 27.35, Heater Set to 20.0
# N = 198, Time = 269.9, T1 = 34.76, T2 = 27.35, Heater Set to 20.0
# N = 199, Time = 271.3, T1 = 34.76, T2 = 27.35, Heater Set to 20.0
# N = 200, Time = 272.6, T1 = 34.76, T2 = 27.67, Heater Set to 20.0
# N = 201, Time = 274.0, T1 = 34.76, T2 = 27.67, Heater Set to 20.0
# N = 202, Time = 275.4, T1 = 34.76, T2 = 27.35, Heater Set to 20.0
# N = 203, Time = 276.7, T1 = 34.76, T2 = 27.67, Heater Set to 20.0
# N = 204, Time = 278.1, T1 = 34.76, T2 = 27.67, Heater Set to 20.0
# N = 205, Time = 279.4, T1 = 34.76, T2 = 27.67, Heater Set to 20.0
# N = 206, Time = 280.8, T1 = 35.09, T2 = 27.67, Heater Set to 20.0
# N = 207, Time = 282.2, T1 = 35.09, T2 = 27.67, Heater Set to 20.0
# N = 208, Time = 283.5, T1 = 35.09, T2 = 27.67, Heater Set to 20.0
# N = 209, Time = 284.9, T1 = 35.09, T2 = 27.67, Heater Set to 20.0
# N = 210, Time = 286.2, T1 = 35.09, T2 = 27.67, Heater Set to 20.0
# N = 211, Time = 287.6, T1 = 35.09, T2 = 27.67, Heater Set to 20.0
# N = 212, Time = 289.0, T1 = 35.09, T2 = 27.67, Heater Set to 20.0
# N = 213, Time = 290.3, T1 = 35.09, T2 = 27.67, Heater Set to 20.0
# N = 214, Time = 291.7, T1 = 35.41, T2 = 27.67, Heater Set to 20.0
# N = 215, Time = 293.0, T1 = 35.09, T2 = 28.0, Heater Set to 20.0
# N = 216, Time = 294.4, T1 = 35.09, T2 = 27.67, Heater Set to 20.0
# N = 217, Time = 295.8, T1 = 35.41, T2 = 27.67, Heater Set to 20.0
# N = 218, Time = 297.1, T1 = 35.41, T2 = 28.0, Heater Set to 20.0
# N = 219, Time = 298.5, T1 = 35.41, T2 = 28.0, Heater Set to 20.0
# N = 220, Time = 299.8, T1 = 35.41, T2 = 28.0, Heater Set to 20.0
# N = 221, Time = 301.2, T1 = 35.41, T2 = 28.0, Heater Set to 20.0
# N = 222, Time = 302.6, T1 = 35.41, T2 = 28.0, Heater Set to 20.0
# N = 223, Time = 303.9, T1 = 35.41, T2 = 28.0, Heater Set to 20.0
# N = 224, Time = 305.3, T1 = 35.73, T2 = 28.0, Heater Set to 20.0
# N = 225, Time = 306.6, T1 = 35.73, T2 = 28.0, Heater Set to 20.0
# N = 226, Time = 308.0, T1 = 35.73, T2 = 28.0, Heater Set to 20.0
# N = 227, Time = 309.3, T1 = 35.73, T2 = 28.0, Heater Set to 20.0
# N = 228, Time = 310.7, T1 = 35.73, T2 = 28.0, Heater Set to 20.0
# N = 229, Time = 312.1, T1 = 35.73, T2 = 28.0, Heater Set to 20.0
# N = 230, Time = 313.4, T1 = 35.73, T2 = 28.0, Heater Set to 20.0
# N = 231, Time = 314.8, T1 = 35.73, T2 = 28.32, Heater Set to 20.0
# N = 232, Time = 316.1, T1 = 35.73, T2 = 28.32, Heater Set to 20.0
# N = 233, Time = 317.5, T1 = 35.73, T2 = 28.0, Heater Set to 20.0
# N = 234, Time = 318.9, T1 = 35.73, T2 = 28.32, Heater Set to 20.0
# N = 235, Time = 320.2, T1 = 35.73, T2 = 28.32, Heater Set to 20.0
# N = 236, Time = 321.6, T1 = 35.09, T2 = 28.32, Heater Set to 20.0
# N = 237, Time = 323.0, T1 = 36.05, T2 = 28.32, Heater Set to 20.0
# N = 238, Time = 324.3, T1 = 35.73, T2 = 28.32, Heater Set to 20.0
# N = 239, Time = 325.7, T1 = 36.05, T2 = 28.32, Heater Set to 20.0
# N = 240, Time = 327.0, T1 = 36.05, T2 = 28.32, Heater Set to 20.0
# N = 241, Time = 328.4, T1 = 36.05, T2 = 28.32, Heater Set to 20.0
# N = 242, Time = 329.8, T1 = 36.05, T2 = 28.32, Heater Set to 20.0
# N = 243, Time = 331.1, T1 = 36.05, T2 = 28.32, Heater Set to 20.0
# N = 244, Time = 332.5, T1 = 36.05, T2 = 28.32, Heater Set to 20.0
# N = 245, Time = 333.9, T1 = 36.05, T2 = 28.32, Heater Set to 20.0
# N = 246, Time = 335.2, T1 = 36.05, T2 = 28.32, Heater Set to 20.0
# N = 247, Time = 336.6, T1 = 36.05, T2 = 28.64, Heater Set to 20.0
# N = 248, Time = 337.9, T1 = 36.05, T2 = 28.64, Heater Set to 20.0
# N = 249, Time = 339.3, T1 = 36.05, T2 = 28.64, Heater Set to 20.0
# N = 250, Time = 340.7, T1 = 36.05, T2 = 28.64, Heater Set to 20.0
# N = 251, Time = 342.0, T1 = 36.38, T2 = 28.64, Heater Set to 20.0
# N = 252, Time = 343.4, T1 = 36.05, T2 = 28.64, Heater Set to 20.0
# N = 253, Time = 344.8, T1 = 36.38, T2 = 28.64, Heater Set to 20.0
# N = 254, Time = 346.1, T1 = 36.38, T2 = 28.64, Heater Set to 20.0
# N = 255, Time = 347.5, T1 = 36.38, T2 = 28.64, Heater Set to 20.0
# N = 256, Time = 348.9, T1 = 36.38, T2 = 28.64, Heater Set to 20.0
# N = 257, Time = 350.2, T1 = 36.38, T2 = 28.64, Heater Set to 20.0
# N = 258, Time = 351.6, T1 = 36.38, T2 = 28.64, Heater Set to 20.0
# N = 259, Time = 353.0, T1 = 36.38, T2 = 28.64, Heater Set to 20.0
# N = 260, Time = 354.3, T1 = 36.38, T2 = 28.64, Heater Set to 20.0
# N = 261, Time = 355.7, T1 = 36.38, T2 = 28.64, Heater Set to 20.0
# N = 262, Time = 357.0, T1 = 36.38, T2 = 28.64, Heater Set to 20.0
# N = 263, Time = 358.4, T1 = 36.38, T2 = 28.64, Heater Set to 20.0
# N = 264, Time = 359.8, T1 = 36.38, T2 = 28.64, Heater Set to 20.0
# N = 265, Time = 361.1, T1 = 36.38, T2 = 28.96, Heater Set to 20.0
# N = 266, Time = 362.5, T1 = 36.7, T2 = 28.64, Heater Set to 20.0
# N = 267, Time = 363.9, T1 = 36.7, T2 = 28.96, Heater Set to 20.0
# N = 268, Time = 365.2, T1 = 36.7, T2 = 28.96, Heater Set to 20.0
# N = 269, Time = 366.6, T1 = 36.7, T2 = 28.96, Heater Set to 20.0
# N = 270, Time = 368.0, T1 = 36.7, T2 = 28.96, Heater Set to 20.0
# N = 271, Time = 369.3, T1 = 36.7, T2 = 28.96, Heater Set to 20.0
# N = 272, Time = 370.7, T1 = 36.7, T2 = 28.96, Heater Set to 20.0
# N = 273, Time = 372.1, T1 = 36.7, T2 = 28.96, Heater Set to 20.0
# N = 274, Time = 373.4, T1 = 36.7, T2 = 28.96, Heater Set to 20.0
# N = 275, Time = 374.8, T1 = 36.7, T2 = 28.96, Heater Set to 20.0
# N = 276, Time = 376.1, T1 = 36.7, T2 = 28.96, Heater Set to 20.0
# N = 277, Time = 377.5, T1 = 36.7, T2 = 28.96, Heater Set to 20.0
# N = 278, Time = 378.9, T1 = 36.7, T2 = 28.96, Heater Set to 20.0
# N = 279, Time = 380.2, T1 = 36.7, T2 = 28.96, Heater Set to 20.0
# N = 280, Time = 381.6, T1 = 36.7, T2 = 28.96, Heater Set to 20.0
# N = 281, Time = 382.9, T1 = 36.7, T2 = 28.96, Heater Set to 20.0
# N = 282, Time = 384.3, T1 = 36.7, T2 = 28.96, Heater Set to 20.0
# N = 283, Time = 385.6, T1 = 37.02, T2 = 29.29, Heater Set to 20.0
# N = 284, Time = 387.0, T1 = 36.7, T2 = 28.96, Heater Set to 20.0
# N = 285, Time = 388.4, T1 = 36.7, T2 = 29.29, Heater Set to 20.0
# N = 286, Time = 389.7, T1 = 36.7, T2 = 29.29, Heater Set to 20.0
# N = 287, Time = 391.1, T1 = 37.02, T2 = 29.29, Heater Set to 20.0
# N = 288, Time = 392.5, T1 = 37.02, T2 = 29.29, Heater Set to 20.0
# N = 289, Time = 393.8, T1 = 37.02, T2 = 29.29, Heater Set to 20.0
# N = 290, Time = 395.2, T1 = 37.02, T2 = 29.29, Heater Set to 20.0
# N = 291, Time = 396.6, T1 = 37.02, T2 = 29.29, Heater Set to 20.0
# N = 292, Time = 397.9, T1 = 37.02, T2 = 29.29, Heater Set to 20.0
# N = 293, Time = 399.3, T1 = 37.02, T2 = 29.29, Heater Set to 20.0
# N = 294, Time = 400.6, T1 = 37.02, T2 = 29.29, Heater Set to 20.0
# N = 295, Time = 402.0, T1 = 37.02, T2 = 29.29, Heater Set to 20.0
# N = 296, Time = 403.3, T1 = 37.02, T2 = 29.29, Heater Set to 20.0
# N = 297, Time = 404.7, T1 = 37.02, T2 = 29.29, Heater Set to 20.0
# N = 298, Time = 406.1, T1 = 37.02, T2 = 29.29, Heater Set to 20.0
# N = 299, Time = 407.5, T1 = 37.02, T2 = 29.29, Heater Set to 20.0
# N = 300, Time = 408.8, T1 = 37.02, T2 = 29.29, Heater Set to 75.0
# N = 301, Time = 410.2, T1 = 37.02, T2 = 29.29, Heater Set to 75.0
# N = 302, Time = 411.5, T1 = 37.02, T2 = 29.29, Heater Set to 75.0
# N = 303, Time = 412.9, T1 = 37.34, T2 = 29.29, Heater Set to 75.0
# N = 304, Time = 414.3, T1 = 37.02, T2 = 29.61, Heater Set to 75.0
# N = 305, Time = 415.6, T1 = 37.34, T2 = 29.61, Heater Set to 75.0
# N = 306, Time = 417.0, T1 = 37.34, T2 = 29.61, Heater Set to 75.0
# N = 307, Time = 418.3, T1 = 37.34, T2 = 29.61, Heater Set to 75.0
# N = 308, Time = 419.7, T1 = 37.34, T2 = 29.61, Heater Set to 75.0
# N = 309, Time = 421.0, T1 = 37.67, T2 = 29.61, Heater Set to 75.0
# N = 310, Time = 422.4, T1 = 37.67, T2 = 29.61, Heater Set to 75.0
# N = 311, Time = 423.7, T1 = 37.67, T2 = 29.61, Heater Set to 75.0
# N = 312, Time = 425.1, T1 = 37.99, T2 = 29.61, Heater Set to 75.0
# N = 313, Time = 426.4, T1 = 37.99, T2 = 29.61, Heater Set to 75.0
# N = 314, Time = 427.8, T1 = 37.99, T2 = 29.61, Heater Set to 75.0
# N = 315, Time = 429.2, T1 = 38.31, T2 = 29.61, Heater Set to 75.0
# N = 316, Time = 430.5, T1 = 38.63, T2 = 29.61, Heater Set to 75.0
# N = 317, Time = 431.9, T1 = 38.63, T2 = 29.61, Heater Set to 75.0
# N = 318, Time = 433.2, T1 = 38.95, T2 = 29.29, Heater Set to 75.0
# N = 319, Time = 434.6, T1 = 38.95, T2 = 29.61, Heater Set to 75.0
# N = 320, Time = 436.0, T1 = 39.28, T2 = 29.61, Heater Set to 75.0
# N = 321, Time = 437.3, T1 = 39.28, T2 = 29.61, Heater Set to 75.0
# N = 322, Time = 438.7, T1 = 39.6, T2 = 29.93, Heater Set to 75.0
# N = 323, Time = 440.0, T1 = 39.92, T2 = 29.61, Heater Set to 75.0
# N = 324, Time = 441.4, T1 = 39.92, T2 = 29.93, Heater Set to 75.0
# N = 325, Time = 442.7, T1 = 39.92, T2 = 29.93, Heater Set to 75.0
# N = 326, Time = 444.1, T1 = 40.24, T2 = 29.93, Heater Set to 75.0
# N = 327, Time = 445.4, T1 = 40.57, T2 = 29.93, Heater Set to 75.0
# N = 328, Time = 446.8, T1 = 40.89, T2 = 29.93, Heater Set to 75.0
# N = 329, Time = 448.2, T1 = 41.21, T2 = 29.93, Heater Set to 75.0
# N = 330, Time = 449.5, T1 = 41.21, T2 = 29.93, Heater Set to 75.0
# N = 331, Time = 450.9, T1 = 41.53, T2 = 29.93, Heater Set to 75.0
# N = 332, Time = 452.2, T1 = 41.53, T2 = 29.93, Heater Set to 75.0
# N = 333, Time = 453.6, T1 = 41.86, T2 = 29.93, Heater Set to 75.0
# N = 334, Time = 454.9, T1 = 42.18, T2 = 29.93, Heater Set to 75.0
# N = 335, Time = 456.3, T1 = 42.18, T2 = 29.93, Heater Set to 75.0
# N = 336, Time = 457.6, T1 = 42.5, T2 = 30.25, Heater Set to 75.0
# N = 337, Time = 459.0, T1 = 42.82, T2 = 30.25, Heater Set to 75.0
# N = 338, Time = 460.3, T1 = 42.82, T2 = 30.25, Heater Set to 75.0
# N = 339, Time = 461.7, T1 = 43.14, T2 = 30.25, Heater Set to 75.0
# N = 340, Time = 463.1, T1 = 43.47, T2 = 30.25, Heater Set to 75.0
# N = 341, Time = 464.4, T1 = 43.79, T2 = 30.25, Heater Set to 75.0
# N = 342, Time = 465.8, T1 = 43.79, T2 = 30.25, Heater Set to 75.0
# N = 343, Time = 467.1, T1 = 44.11, T2 = 30.57, Heater Set to 75.0
# N = 344, Time = 468.5, T1 = 44.43, T2 = 30.57, Heater Set to 75.0
# N = 345, Time = 469.9, T1 = 44.76, T2 = 30.57, Heater Set to 75.0
# N = 346, Time = 471.2, T1 = 44.76, T2 = 30.57, Heater Set to 75.0
# N = 347, Time = 472.6, T1 = 45.08, T2 = 30.57, Heater Set to 75.0
# N = 348, Time = 473.9, T1 = 45.08, T2 = 30.57, Heater Set to 75.0
# N = 349, Time = 475.3, T1 = 45.4, T2 = 30.57, Heater Set to 75.0
# N = 350, Time = 476.6, T1 = 45.72, T2 = 30.57, Heater Set to 75.0
# N = 351, Time = 478.0, T1 = 46.05, T2 = 30.9, Heater Set to 75.0
# N = 352, Time = 479.3, T1 = 46.05, T2 = 30.9, Heater Set to 75.0
# N = 353, Time = 480.7, T1 = 46.37, T2 = 30.9, Heater Set to 75.0
# N = 354, Time = 482.0, T1 = 46.69, T2 = 30.9, Heater Set to 75.0
# N = 355, Time = 483.4, T1 = 47.01, T2 = 30.9, Heater Set to 75.0
# N = 356, Time = 484.8, T1 = 47.01, T2 = 30.9, Heater Set to 75.0
# N = 357, Time = 486.1, T1 = 47.33, T2 = 31.22, Heater Set to 75.0
# N = 358, Time = 487.5, T1 = 47.33, T2 = 30.9, Heater Set to 75.0
# N = 359, Time = 488.8, T1 = 47.66, T2 = 31.22, Heater Set to 75.0
# N = 360, Time = 490.2, T1 = 47.98, T2 = 31.22, Heater Set to 75.0
# N = 361, Time = 491.5, T1 = 47.98, T2 = 31.22, Heater Set to 75.0
# N = 362, Time = 492.9, T1 = 48.3, T2 = 31.22, Heater Set to 75.0
# N = 363, Time = 494.2, T1 = 48.62, T2 = 31.54, Heater Set to 75.0
# N = 364, Time = 495.6, T1 = 48.62, T2 = 31.54, Heater Set to 75.0
# N = 365, Time = 497.0, T1 = 48.95, T2 = 31.54, Heater Set to 75.0
# N = 366, Time = 498.3, T1 = 49.27, T2 = 31.54, Heater Set to 75.0
# N = 367, Time = 499.7, T1 = 49.59, T2 = 31.54, Heater Set to 75.0
# N = 368, Time = 501.0, T1 = 49.59, T2 = 31.54, Heater Set to 75.0
# N = 369, Time = 502.4, T1 = 49.59, T2 = 31.54, Heater Set to 75.0
# N = 370, Time = 503.8, T1 = 49.91, T2 = 31.86, Heater Set to 75.0
# N = 371, Time = 505.1, T1 = 50.24, T2 = 31.86, Heater Set to 75.0
# N = 372, Time = 506.5, T1 = 50.24, T2 = 31.86, Heater Set to 75.0
# N = 373, Time = 507.9, T1 = 50.56, T2 = 31.86, Heater Set to 75.0
# N = 374, Time = 509.2, T1 = 50.88, T2 = 31.86, Heater Set to 75.0
# N = 375, Time = 510.6, T1 = 50.88, T2 = 31.86, Heater Set to 75.0
# N = 376, Time = 511.9, T1 = 50.88, T2 = 31.86, Heater Set to 75.0
# N = 377, Time = 513.3, T1 = 51.2, T2 = 32.19, Heater Set to 75.0
# N = 378, Time = 514.6, T1 = 51.2, T2 = 32.19, Heater Set to 75.0
# N = 379, Time = 516.0, T1 = 51.52, T2 = 32.19, Heater Set to 75.0
# N = 380, Time = 517.3, T1 = 51.85, T2 = 32.19, Heater Set to 75.0
# N = 381, Time = 518.7, T1 = 52.17, T2 = 32.19, Heater Set to 75.0
# N = 382, Time = 520.0, T1 = 52.17, T2 = 32.51, Heater Set to 75.0
# N = 383, Time = 521.4, T1 = 52.49, T2 = 32.51, Heater Set to 75.0
# N = 384, Time = 522.7, T1 = 52.49, T2 = 32.51, Heater Set to 75.0
# N = 385, Time = 524.1, T1 = 52.81, T2 = 32.51, Heater Set to 75.0
# N = 386, Time = 525.5, T1 = 52.81, T2 = 32.51, Heater Set to 75.0
# N = 387, Time = 526.8, T1 = 53.14, T2 = 32.51, Heater Set to 75.0
# N = 388, Time = 528.2, T1 = 53.14, T2 = 32.51, Heater Set to 75.0
# N = 389, Time = 529.5, T1 = 53.46, T2 = 32.83, Heater Set to 75.0
# N = 390, Time = 530.9, T1 = 53.46, T2 = 32.83, Heater Set to 75.0
# N = 391, Time = 532.3, T1 = 53.78, T2 = 32.83, Heater Set to 75.0
# N = 392, Time = 533.6, T1 = 53.78, T2 = 32.83, Heater Set to 75.0
# N = 393, Time = 535.0, T1 = 54.1, T2 = 33.15, Heater Set to 75.0
# N = 394, Time = 536.3, T1 = 54.43, T2 = 33.15, Heater Set to 75.0
# N = 395, Time = 537.7, T1 = 54.43, T2 = 33.15, Heater Set to 75.0
# N = 396, Time = 539.1, T1 = 54.75, T2 = 33.15, Heater Set to 75.0
# N = 397, Time = 540.4, T1 = 54.75, T2 = 33.15, Heater Set to 75.0
# N = 398, Time = 541.8, T1 = 54.75, T2 = 33.15, Heater Set to 75.0
# N = 399, Time = 543.2, T1 = 55.07, T2 = 33.15, Heater Set to 75.0
# N = 400, Time = 544.5, T1 = 55.39, T2 = 33.48, Heater Set to 75.0
# N = 401, Time = 545.9, T1 = 55.39, T2 = 33.48, Heater Set to 75.0
# N = 402, Time = 547.2, T1 = 55.71, T2 = 33.48, Heater Set to 75.0
# N = 403, Time = 548.6, T1 = 55.71, T2 = 33.48, Heater Set to 75.0
# N = 404, Time = 549.9, T1 = 56.04, T2 = 33.48, Heater Set to 75.0
# N = 405, Time = 551.3, T1 = 56.04, T2 = 33.8, Heater Set to 75.0
# N = 406, Time = 552.7, T1 = 56.36, T2 = 33.8, Heater Set to 75.0
# N = 407, Time = 554.0, T1 = 56.36, T2 = 33.8, Heater Set to 75.0
# N = 408, Time = 555.4, T1 = 56.36, T2 = 33.8, Heater Set to 75.0
# N = 409, Time = 556.7, T1 = 56.68, T2 = 33.8, Heater Set to 75.0
# N = 410, Time = 558.1, T1 = 56.68, T2 = 34.12, Heater Set to 75.0
# N = 411, Time = 559.4, T1 = 57.0, T2 = 34.12, Heater Set to 75.0
# N = 412, Time = 560.8, T1 = 57.0, T2 = 34.12, Heater Set to 75.0
# N = 413, Time = 562.2, T1 = 57.33, T2 = 34.12, Heater Set to 75.0
# N = 414, Time = 563.5, T1 = 57.33, T2 = 34.12, Heater Set to 75.0
# N = 415, Time = 564.9, T1 = 57.33, T2 = 34.44, Heater Set to 75.0
# N = 416, Time = 566.2, T1 = 57.65, T2 = 34.44, Heater Set to 75.0
# N = 417, Time = 567.6, T1 = 57.65, T2 = 34.44, Heater Set to 75.0
# N = 418, Time = 569.0, T1 = 57.97, T2 = 34.44, Heater Set to 75.0
# N = 419, Time = 570.3, T1 = 58.29, T2 = 34.76, Heater Set to 75.0
# N = 420, Time = 571.7, T1 = 58.29, T2 = 34.76, Heater Set to 75.0
# N = 421, Time = 573.0, T1 = 58.29, T2 = 34.76, Heater Set to 75.0
# N = 422, Time = 574.4, T1 = 58.62, T2 = 34.76, Heater Set to 75.0
# N = 423, Time = 575.8, T1 = 58.62, T2 = 34.76, Heater Set to 75.0
# N = 424, Time = 577.1, T1 = 58.62, T2 = 35.09, Heater Set to 75.0
# N = 425, Time = 578.5, T1 = 58.62, T2 = 35.09, Heater Set to 75.0
# N = 426, Time = 579.8, T1 = 58.62, T2 = 35.09, Heater Set to 75.0
# N = 427, Time = 581.2, T1 = 58.94, T2 = 35.09, Heater Set to 75.0
# N = 428, Time = 582.5, T1 = 59.26, T2 = 35.09, Heater Set to 75.0
# N = 429, Time = 583.9, T1 = 59.26, T2 = 35.09, Heater Set to 75.0
# N = 430, Time = 585.3, T1 = 59.26, T2 = 35.41, Heater Set to 75.0
# N = 431, Time = 586.6, T1 = 59.58, T2 = 35.41, Heater Set to 75.0
# N = 432, Time = 588.0, T1 = 59.58, T2 = 35.09, Heater Set to 75.0
# N = 433, Time = 589.3, T1 = 59.58, T2 = 35.41, Heater Set to 75.0
# N = 434, Time = 590.7, T1 = 59.9, T2 = 35.41, Heater Set to 75.0
# N = 435, Time = 592.1, T1 = 59.9, T2 = 35.73, Heater Set to 75.0
# N = 436, Time = 593.4, T1 = 59.9, T2 = 35.73, Heater Set to 75.0
# N = 437, Time = 594.8, T1 = 60.23, T2 = 35.73, Heater Set to 75.0
# N = 438, Time = 596.1, T1 = 60.55, T2 = 35.73, Heater Set to 75.0
# N = 439, Time = 597.5, T1 = 60.55, T2 = 35.73, Heater Set to 75.0
# N = 440, Time = 598.8, T1 = 60.55, T2 = 35.73, Heater Set to 75.0
# N = 441, Time = 600.2, T1 = 60.87, T2 = 36.05, Heater Set to 75.0
# N = 442, Time = 601.6, T1 = 60.55, T2 = 36.05, Heater Set to 75.0
# N = 443, Time = 602.9, T1 = 60.87, T2 = 36.05, Heater Set to 75.0
# N = 444, Time = 604.3, T1 = 61.19, T2 = 36.05, Heater Set to 75.0
# N = 445, Time = 605.6, T1 = 61.19, T2 = 36.05, Heater Set to 75.0
# N = 446, Time = 607.0, T1 = 61.19, T2 = 36.05, Heater Set to 75.0
# N = 447, Time = 608.4, T1 = 61.52, T2 = 36.38, Heater Set to 75.0
# N = 448, Time = 609.7, T1 = 61.52, T2 = 36.38, Heater Set to 75.0
# N = 449, Time = 611.1, T1 = 61.52, T2 = 36.38, Heater Set to 75.0
# N = 450, Time = 612.4, T1 = 61.52, T2 = 36.38, Heater Set to 75.0
# N = 451, Time = 613.8, T1 = 61.84, T2 = 36.38, Heater Set to 75.0
# N = 452, Time = 615.2, T1 = 61.84, T2 = 36.7, Heater Set to 75.0
# N = 453, Time = 616.5, T1 = 61.84, T2 = 36.7, Heater Set to 75.0
# N = 454, Time = 617.9, T1 = 62.16, T2 = 36.7, Heater Set to 75.0
# N = 455, Time = 619.2, T1 = 62.16, T2 = 36.7, Heater Set to 75.0
# N = 456, Time = 620.6, T1 = 62.48, T2 = 36.7, Heater Set to 75.0
# N = 457, Time = 621.9, T1 = 62.48, T2 = 36.7, Heater Set to 75.0
# N = 458, Time = 623.3, T1 = 62.8, T2 = 37.02, Heater Set to 75.0
# N = 459, Time = 624.7, T1 = 62.8, T2 = 37.02, Heater Set to 75.0
# N = 460, Time = 626.0, T1 = 62.8, T2 = 37.02, Heater Set to 75.0
# N = 461, Time = 627.4, T1 = 62.8, T2 = 37.02, Heater Set to 75.0
# N = 462, Time = 628.7, T1 = 63.13, T2 = 37.02, Heater Set to 75.0
# N = 463, Time = 630.1, T1 = 63.13, T2 = 37.34, Heater Set to 75.0
# N = 464, Time = 631.4, T1 = 63.13, T2 = 37.34, Heater Set to 75.0
# N = 465, Time = 632.8, T1 = 63.13, T2 = 37.34, Heater Set to 75.0
# N = 466, Time = 634.2, T1 = 63.45, T2 = 37.34, Heater Set to 75.0
# N = 467, Time = 635.5, T1 = 63.45, T2 = 37.34, Heater Set to 75.0
# N = 468, Time = 636.9, T1 = 63.45, T2 = 37.67, Heater Set to 75.0
# N = 469, Time = 638.2, T1 = 63.77, T2 = 37.67, Heater Set to 75.0
# N = 470, Time = 639.6, T1 = 63.77, T2 = 37.67, Heater Set to 75.0
# N = 471, Time = 640.9, T1 = 63.77, T2 = 37.67, Heater Set to 75.0
# N = 472, Time = 642.3, T1 = 64.09, T2 = 37.67, Heater Set to 75.0
# N = 473, Time = 643.6, T1 = 63.77, T2 = 37.67, Heater Set to 75.0
# N = 474, Time = 645.0, T1 = 64.09, T2 = 37.67, Heater Set to 75.0
# N = 475, Time = 646.3, T1 = 64.09, T2 = 37.99, Heater Set to 75.0
# N = 476, Time = 647.7, T1 = 64.42, T2 = 37.99, Heater Set to 75.0
# N = 477, Time = 649.1, T1 = 64.42, T2 = 37.99, Heater Set to 75.0
# N = 478, Time = 650.4, T1 = 64.42, T2 = 37.99, Heater Set to 75.0
# N = 479, Time = 651.8, T1 = 64.42, T2 = 37.99, Heater Set to 75.0
# N = 480, Time = 653.1, T1 = 64.42, T2 = 38.31, Heater Set to 75.0
# N = 481, Time = 654.5, T1 = 64.42, T2 = 37.99, Heater Set to 75.0
# N = 482, Time = 655.9, T1 = 64.42, T2 = 38.31, Heater Set to 75.0
# N = 483, Time = 657.2, T1 = 64.74, T2 = 38.31, Heater Set to 75.0
# N = 484, Time = 658.6, T1 = 64.42, T2 = 38.31, Heater Set to 75.0
# N = 485, Time = 659.9, T1 = 64.74, T2 = 38.31, Heater Set to 75.0
# N = 486, Time = 661.3, T1 = 64.74, T2 = 38.63, Heater Set to 75.0
# N = 487, Time = 662.6, T1 = 64.74, T2 = 38.31, Heater Set to 75.0
# N = 488, Time = 664.0, T1 = 64.74, T2 = 38.63, Heater Set to 75.0
# N = 489, Time = 665.3, T1 = 65.06, T2 = 38.63, Heater Set to 75.0
# N = 490, Time = 666.7, T1 = 65.06, T2 = 38.63, Heater Set to 75.0
# N = 491, Time = 668.1, T1 = 65.06, T2 = 38.63, Heater Set to 75.0
# N = 492, Time = 669.4, T1 = 65.38, T2 = 38.63, Heater Set to 75.0
# N = 493, Time = 670.8, T1 = 65.38, T2 = 38.63, Heater Set to 75.0
# N = 494, Time = 672.1, T1 = 65.38, T2 = 38.95, Heater Set to 75.0
# N = 495, Time = 673.5, T1 = 65.71, T2 = 38.95, Heater Set to 75.0
# N = 496, Time = 674.9, T1 = 65.71, T2 = 38.95, Heater Set to 75.0
# N = 497, Time = 676.2, T1 = 65.71, T2 = 38.95, Heater Set to 75.0
# N = 498, Time = 677.6, T1 = 66.03, T2 = 38.95, Heater Set to 75.0
# N = 499, Time = 678.9, T1 = 66.03, T2 = 39.28, Heater Set to 75.0
# N = 500, Time = 680.3, T1 = 66.03, T2 = 39.28, Heater Set to 75.0
# N = 501, Time = 681.6, T1 = 66.03, T2 = 39.28, Heater Set to 75.0
# N = 502, Time = 683.0, T1 = 66.35, T2 = 39.28, Heater Set to 75.0
# N = 503, Time = 684.4, T1 = 66.35, T2 = 39.28, Heater Set to 75.0
# N = 504, Time = 685.7, T1 = 66.35, T2 = 39.28, Heater Set to 75.0
# N = 505, Time = 687.1, T1 = 65.71, T2 = 39.28, Heater Set to 75.0
# N = 506, Time = 688.4, T1 = 66.35, T2 = 39.28, Heater Set to 75.0
# N = 507, Time = 689.8, T1 = 66.35, T2 = 39.28, Heater Set to 75.0
# N = 508, Time = 691.1, T1 = 66.35, T2 = 39.6, Heater Set to 75.0
# N = 509, Time = 692.5, T1 = 66.35, T2 = 39.6, Heater Set to 75.0
# N = 510, Time = 693.8, T1 = 66.35, T2 = 39.6, Heater Set to 75.0
# N = 511, Time = 695.2, T1 = 66.35, T2 = 39.6, Heater Set to 75.0
# N = 512, Time = 696.5, T1 = 66.67, T2 = 39.6, Heater Set to 75.0
# N = 513, Time = 697.9, T1 = 66.67, T2 = 39.6, Heater Set to 75.0
# N = 514, Time = 699.3, T1 = 66.67, T2 = 39.6, Heater Set to 75.0
# N = 515, Time = 700.6, T1 = 66.67, T2 = 39.92, Heater Set to 75.0
# N = 516, Time = 702.0, T1 = 66.99, T2 = 39.92, Heater Set to 75.0
# N = 517, Time = 703.3, T1 = 66.99, T2 = 39.92, Heater Set to 75.0
# N = 518, Time = 704.7, T1 = 66.99, T2 = 39.92, Heater Set to 75.0
# N = 519, Time = 706.0, T1 = 67.32, T2 = 40.24, Heater Set to 75.0
# N = 520, Time = 707.4, T1 = 67.32, T2 = 40.24, Heater Set to 75.0
# N = 521, Time = 708.8, T1 = 67.32, T2 = 40.24, Heater Set to 75.0
# N = 522, Time = 710.1, T1 = 67.32, T2 = 40.24, Heater Set to 75.0
# N = 523, Time = 711.5, T1 = 67.64, T2 = 40.24, Heater Set to 75.0
# N = 524, Time = 712.8, T1 = 67.64, T2 = 40.24, Heater Set to 75.0
# N = 525, Time = 714.2, T1 = 67.64, T2 = 40.24, Heater Set to 75.0
# N = 526, Time = 715.6, T1 = 67.64, T2 = 40.24, Heater Set to 75.0
# N = 527, Time = 716.9, T1 = 67.64, T2 = 40.57, Heater Set to 75.0
# N = 528, Time = 718.3, T1 = 67.64, T2 = 40.57, Heater Set to 75.0
# N = 529, Time = 719.6, T1 = 67.96, T2 = 40.57, Heater Set to 75.0
# N = 530, Time = 721.0, T1 = 67.96, T2 = 40.57, Heater Set to 75.0
# N = 531, Time = 722.3, T1 = 67.96, T2 = 40.57, Heater Set to 75.0
# N = 532, Time = 723.7, T1 = 67.96, T2 = 40.57, Heater Set to 75.0
# N = 533, Time = 725.1, T1 = 67.96, T2 = 40.57, Heater Set to 75.0
# N = 534, Time = 726.4, T1 = 67.96, T2 = 40.57, Heater Set to 75.0
# N = 535, Time = 727.8, T1 = 68.28, T2 = 40.89, Heater Set to 75.0
# N = 536, Time = 729.1, T1 = 68.28, T2 = 40.89, Heater Set to 75.0
# N = 537, Time = 730.5, T1 = 68.28, T2 = 40.89, Heater Set to 75.0
# N = 538, Time = 731.8, T1 = 68.28, T2 = 40.89, Heater Set to 75.0
# N = 539, Time = 733.2, T1 = 68.28, T2 = 40.57, Heater Set to 75.0
# N = 540, Time = 734.5, T1 = 68.61, T2 = 40.89, Heater Set to 75.0
# N = 541, Time = 735.9, T1 = 68.28, T2 = 41.21, Heater Set to 75.0
# N = 542, Time = 737.2, T1 = 68.61, T2 = 41.21, Heater Set to 75.0
# N = 543, Time = 738.6, T1 = 68.61, T2 = 41.21, Heater Set to 75.0
# N = 544, Time = 739.9, T1 = 68.61, T2 = 41.21, Heater Set to 75.0
# N = 545, Time = 741.3, T1 = 68.61, T2 = 41.21, Heater Set to 75.0
# N = 546, Time = 742.6, T1 = 68.61, T2 = 41.21, Heater Set to 75.0
# N = 547, Time = 744.0, T1 = 68.61, T2 = 41.21, Heater Set to 75.0
# N = 548, Time = 745.4, T1 = 68.61, T2 = 41.21, Heater Set to 75.0
# N = 549, Time = 746.7, T1 = 68.61, T2 = 41.21, Heater Set to 75.0
# N = 550, Time = 748.1, T1 = 68.61, T2 = 41.21, Heater Set to 75.0
# N = 551, Time = 749.4, T1 = 68.93, T2 = 41.53, Heater Set to 75.0
# N = 552, Time = 750.8, T1 = 68.93, T2 = 41.53, Heater Set to 75.0
# N = 553, Time = 752.1, T1 = 69.25, T2 = 41.53, Heater Set to 75.0
# N = 554, Time = 753.5, T1 = 69.25, T2 = 41.53, Heater Set to 75.0
# N = 555, Time = 754.9, T1 = 69.25, T2 = 41.53, Heater Set to 75.0
# N = 556, Time = 756.2, T1 = 69.25, T2 = 41.86, Heater Set to 75.0
# N = 557, Time = 757.6, T1 = 69.25, T2 = 41.53, Heater Set to 75.0
# N = 558, Time = 758.9, T1 = 68.93, T2 = 41.86, Heater Set to 75.0
# N = 559, Time = 760.3, T1 = 69.25, T2 = 41.53, Heater Set to 75.0
# N = 560, Time = 761.6, T1 = 68.93, T2 = 41.86, Heater Set to 75.0
# N = 561, Time = 763.0, T1 = 69.25, T2 = 41.86, Heater Set to 75.0
# N = 562, Time = 764.3, T1 = 69.25, T2 = 41.86, Heater Set to 75.0
# N = 563, Time = 765.7, T1 = 69.25, T2 = 41.86, Heater Set to 75.0
# N = 564, Time = 767.0, T1 = 69.25, T2 = 41.86, Heater Set to 75.0
# N = 565, Time = 768.4, T1 = 69.25, T2 = 41.86, Heater Set to 75.0
# N = 566, Time = 769.8, T1 = 69.25, T2 = 41.86, Heater Set to 75.0
# N = 567, Time = 771.1, T1 = 69.57, T2 = 41.86, Heater Set to 75.0
# N = 568, Time = 772.5, T1 = 69.57, T2 = 42.18, Heater Set to 75.0
# N = 569, Time = 773.8, T1 = 69.57, T2 = 42.18, Heater Set to 75.0
# N = 570, Time = 775.2, T1 = 69.9, T2 = 42.18, Heater Set to 75.0
# N = 571, Time = 776.5, T1 = 69.9, T2 = 42.18, Heater Set to 75.0
# N = 572, Time = 777.9, T1 = 69.25, T2 = 42.18, Heater Set to 75.0
# N = 573, Time = 779.2, T1 = 69.9, T2 = 42.18, Heater Set to 75.0
# N = 574, Time = 780.6, T1 = 69.9, T2 = 42.18, Heater Set to 75.0
# N = 575, Time = 782.0, T1 = 69.9, T2 = 42.18, Heater Set to 75.0
# N = 576, Time = 783.3, T1 = 69.57, T2 = 42.18, Heater Set to 75.0
# N = 577, Time = 784.7, T1 = 69.9, T2 = 42.5, Heater Set to 75.0
# N = 578, Time = 786.0, T1 = 69.9, T2 = 42.5, Heater Set to 75.0
# N = 579, Time = 787.4, T1 = 69.57, T2 = 42.18, Heater Set to 75.0
# N = 580, Time = 788.7, T1 = 69.57, T2 = 42.5, Heater Set to 75.0
# N = 581, Time = 790.1, T1 = 69.57, T2 = 42.5, Heater Set to 75.0
# N = 582, Time = 791.5, T1 = 69.57, T2 = 42.5, Heater Set to 75.0
# N = 583, Time = 792.8, T1 = 69.57, T2 = 42.5, Heater Set to 75.0
# N = 584, Time = 794.2, T1 = 69.9, T2 = 42.5, Heater Set to 75.0
# N = 585, Time = 795.5, T1 = 69.9, T2 = 42.82, Heater Set to 75.0
# N = 586, Time = 796.9, T1 = 69.9, T2 = 42.5, Heater Set to 75.0
# N = 587, Time = 798.2, T1 = 69.9, T2 = 42.5, Heater Set to 75.0
# N = 588, Time = 799.6, T1 = 69.9, T2 = 42.82, Heater Set to 75.0
# N = 589, Time = 800.9, T1 = 69.9, T2 = 42.82, Heater Set to 75.0
# N = 590, Time = 802.3, T1 = 69.9, T2 = 42.82, Heater Set to 75.0
# N = 591, Time = 803.7, T1 = 69.9, T2 = 42.82, Heater Set to 75.0
# N = 592, Time = 805.0, T1 = 69.9, T2 = 42.82, Heater Set to 75.0
# N = 593, Time = 806.4, T1 = 69.9, T2 = 42.82, Heater Set to 75.0
# N = 594, Time = 807.7, T1 = 69.9, T2 = 42.82, Heater Set to 75.0
# N = 595, Time = 809.1, T1 = 69.9, T2 = 42.82, Heater Set to 75.0
# N = 596, Time = 810.4, T1 = 69.9, T2 = 42.82, Heater Set to 75.0
# N = 597, Time = 811.8, T1 = 69.9, T2 = 42.82, Heater Set to 75.0
# N = 598, Time = 813.1, T1 = 69.9, T2 = 42.82, Heater Set to 75.0
# N = 599, Time = 814.5, T1 = 69.9, T2 = 42.82, Heater Set to 75.0
# N = 600, Time = 815.8, T1 = 69.9, T2 = 42.82, Heater Set to 0.0
# N = 601, Time = 817.1, T1 = 69.9, T2 = 42.82, Heater Set to 0.0
# N = 602, Time = 818.5, T1 = 69.9, T2 = 42.82, Heater Set to 0.0
# N = 603, Time = 819.8, T1 = 70.22, T2 = 42.82, Heater Set to 0.0
# N = 604, Time = 821.1, T1 = 70.22, T2 = 42.82, Heater Set to 0.0
# N = 605, Time = 822.4, T1 = 70.22, T2 = 43.14, Heater Set to 0.0
# N = 606, Time = 823.7, T1 = 70.22, T2 = 43.14, Heater Set to 0.0
# N = 607, Time = 825.1, T1 = 70.22, T2 = 43.14, Heater Set to 0.0
# N = 608, Time = 826.4, T1 = 69.9, T2 = 43.14, Heater Set to 0.0
# N = 609, Time = 827.7, T1 = 69.9, T2 = 43.14, Heater Set to 0.0
# N = 610, Time = 829.1, T1 = 69.9, T2 = 43.14, Heater Set to 0.0
# N = 611, Time = 830.4, T1 = 69.9, T2 = 43.14, Heater Set to 0.0
# N = 612, Time = 831.7, T1 = 69.57, T2 = 43.14, Heater Set to 0.0
# N = 613, Time = 833.0, T1 = 69.57, T2 = 43.14, Heater Set to 0.0
# N = 614, Time = 834.4, T1 = 69.57, T2 = 43.14, Heater Set to 0.0
# N = 615, Time = 835.7, T1 = 69.25, T2 = 43.14, Heater Set to 0.0
# N = 616, Time = 837.0, T1 = 68.93, T2 = 43.14, Heater Set to 0.0
# N = 617, Time = 838.3, T1 = 68.93, T2 = 43.14, Heater Set to 0.0
# N = 618, Time = 839.7, T1 = 68.93, T2 = 43.14, Heater Set to 0.0
# N = 619, Time = 841.0, T1 = 68.61, T2 = 43.14, Heater Set to 0.0
# N = 620, Time = 842.3, T1 = 68.28, T2 = 43.14, Heater Set to 0.0
# N = 621, Time = 843.7, T1 = 68.28, T2 = 43.14, Heater Set to 0.0
# N = 622, Time = 845.0, T1 = 67.96, T2 = 43.14, Heater Set to 0.0
# N = 623, Time = 846.3, T1 = 67.64, T2 = 43.14, Heater Set to 0.0
# N = 624, Time = 847.6, T1 = 67.64, T2 = 43.14, Heater Set to 0.0
# N = 625, Time = 848.9, T1 = 67.32, T2 = 43.14, Heater Set to 0.0
# N = 626, Time = 850.3, T1 = 67.32, T2 = 43.14, Heater Set to 0.0
# N = 627, Time = 851.6, T1 = 66.99, T2 = 43.14, Heater Set to 0.0
# N = 628, Time = 852.9, T1 = 66.99, T2 = 43.14, Heater Set to 0.0
# N = 629, Time = 854.2, T1 = 66.67, T2 = 43.14, Heater Set to 0.0
# N = 630, Time = 855.6, T1 = 66.35, T2 = 43.14, Heater Set to 0.0
# N = 631, Time = 856.9, T1 = 66.35, T2 = 43.14, Heater Set to 0.0
# N = 632, Time = 858.2, T1 = 66.03, T2 = 43.14, Heater Set to 0.0
# N = 633, Time = 859.5, T1 = 65.71, T2 = 43.14, Heater Set to 0.0
# N = 634, Time = 860.9, T1 = 65.38, T2 = 42.82, Heater Set to 0.0
# N = 635, Time = 862.2, T1 = 65.06, T2 = 43.14, Heater Set to 0.0
# N = 636, Time = 863.5, T1 = 64.74, T2 = 43.14, Heater Set to 0.0
# N = 637, Time = 864.9, T1 = 64.42, T2 = 43.14, Heater Set to 0.0
# N = 638, Time = 866.2, T1 = 64.09, T2 = 43.14, Heater Set to 0.0
# N = 639, Time = 867.5, T1 = 63.77, T2 = 43.14, Heater Set to 0.0
# N = 640, Time = 868.8, T1 = 63.45, T2 = 43.14, Heater Set to 0.0
# N = 641, Time = 870.2, T1 = 63.45, T2 = 43.14, Heater Set to 0.0
# N = 642, Time = 871.5, T1 = 63.13, T2 = 42.82, Heater Set to 0.0
# N = 643, Time = 872.8, T1 = 62.8, T2 = 43.14, Heater Set to 0.0
# N = 644, Time = 874.1, T1 = 62.48, T2 = 43.14, Heater Set to 0.0
# N = 645, Time = 875.4, T1 = 62.16, T2 = 42.82, Heater Set to 0.0
# N = 646, Time = 876.8, T1 = 62.16, T2 = 42.82, Heater Set to 0.0
# N = 647, Time = 878.1, T1 = 61.84, T2 = 42.82, Heater Set to 0.0
# N = 648, Time = 879.4, T1 = 61.52, T2 = 42.82, Heater Set to 0.0
# N = 649, Time = 880.7, T1 = 61.19, T2 = 42.82, Heater Set to 0.0
# N = 650, Time = 882.1, T1 = 60.87, T2 = 42.82, Heater Set to 0.0
# N = 651, Time = 883.4, T1 = 60.55, T2 = 42.82, Heater Set to 0.0
# N = 652, Time = 884.7, T1 = 60.23, T2 = 42.82, Heater Set to 0.0
# N = 653, Time = 886.1, T1 = 59.9, T2 = 42.82, Heater Set to 0.0
# N = 654, Time = 887.4, T1 = 59.9, T2 = 42.82, Heater Set to 0.0
# N = 655, Time = 888.7, T1 = 59.58, T2 = 42.82, Heater Set to 0.0
# N = 656, Time = 890.0, T1 = 59.26, T2 = 42.82, Heater Set to 0.0
# N = 657, Time = 891.4, T1 = 58.94, T2 = 42.82, Heater Set to 0.0
# N = 658, Time = 892.7, T1 = 58.62, T2 = 42.5, Heater Set to 0.0
# N = 659, Time = 894.0, T1 = 58.29, T2 = 42.5, Heater Set to 0.0
# N = 660, Time = 895.4, T1 = 58.29, T2 = 42.5, Heater Set to 0.0
# N = 661, Time = 896.7, T1 = 57.65, T2 = 42.5, Heater Set to 0.0
# N = 662, Time = 898.0, T1 = 57.65, T2 = 42.5, Heater Set to 0.0
# N = 663, Time = 899.3, T1 = 57.33, T2 = 42.18, Heater Set to 0.0
# N = 664, Time = 900.6, T1 = 57.33, T2 = 42.5, Heater Set to 0.0
# N = 665, Time = 902.0, T1 = 57.0, T2 = 42.5, Heater Set to 0.0
# N = 666, Time = 903.3, T1 = 56.68, T2 = 42.18, Heater Set to 0.0
# N = 667, Time = 904.6, T1 = 56.36, T2 = 42.18, Heater Set to 0.0
# N = 668, Time = 906.0, T1 = 56.36, T2 = 42.18, Heater Set to 0.0
# N = 669, Time = 907.3, T1 = 56.04, T2 = 42.18, Heater Set to 0.0
# N = 670, Time = 908.6, T1 = 55.71, T2 = 42.18, Heater Set to 0.0
# N = 671, Time = 909.9, T1 = 55.39, T2 = 41.86, Heater Set to 0.0
# N = 672, Time = 911.3, T1 = 55.39, T2 = 42.18, Heater Set to 0.0
# N = 673, Time = 912.6, T1 = 55.07, T2 = 42.18, Heater Set to 0.0
# N = 674, Time = 913.9, T1 = 54.75, T2 = 41.86, Heater Set to 0.0
# N = 675, Time = 915.2, T1 = 54.43, T2 = 41.86, Heater Set to 0.0
# N = 676, Time = 916.6, T1 = 54.1, T2 = 41.86, Heater Set to 0.0
# N = 677, Time = 917.9, T1 = 54.1, T2 = 41.86, Heater Set to 0.0
# N = 678, Time = 919.2, T1 = 53.78, T2 = 41.86, Heater Set to 0.0
# N = 679, Time = 920.5, T1 = 53.46, T2 = 41.86, Heater Set to 0.0
# N = 680, Time = 921.9, T1 = 53.46, T2 = 41.86, Heater Set to 0.0
# N = 681, Time = 923.2, T1 = 53.14, T2 = 41.53, Heater Set to 0.0
# N = 682, Time = 924.5, T1 = 53.14, T2 = 41.53, Heater Set to 0.0
# N = 683, Time = 925.8, T1 = 52.81, T2 = 41.53, Heater Set to 0.0
# N = 684, Time = 927.1, T1 = 52.49, T2 = 41.53, Heater Set to 0.0
# N = 685, Time = 928.5, T1 = 52.49, T2 = 41.53, Heater Set to 0.0
# N = 686, Time = 929.8, T1 = 52.17, T2 = 41.21, Heater Set to 0.0
# N = 687, Time = 931.1, T1 = 51.85, T2 = 41.21, Heater Set to 0.0
# N = 688, Time = 932.4, T1 = 51.85, T2 = 41.21, Heater Set to 0.0
# N = 689, Time = 933.8, T1 = 51.52, T2 = 41.21, Heater Set to 0.0
# N = 690, Time = 935.1, T1 = 51.2, T2 = 41.21, Heater Set to 0.0
# N = 691, Time = 936.4, T1 = 50.88, T2 = 41.21, Heater Set to 0.0
# N = 692, Time = 937.7, T1 = 50.88, T2 = 40.89, Heater Set to 0.0
# N = 693, Time = 939.1, T1 = 50.56, T2 = 40.89, Heater Set to 0.0
# N = 694, Time = 940.4, T1 = 50.24, T2 = 40.89, Heater Set to 0.0
# N = 695, Time = 941.7, T1 = 50.24, T2 = 40.89, Heater Set to 0.0
# N = 696, Time = 943.0, T1 = 49.91, T2 = 40.89, Heater Set to 0.0
# N = 697, Time = 944.4, T1 = 49.91, T2 = 40.89, Heater Set to 0.0
# N = 698, Time = 945.7, T1 = 49.59, T2 = 40.89, Heater Set to 0.0
# N = 699, Time = 947.0, T1 = 49.27, T2 = 40.57, Heater Set to 0.0
# N = 700, Time = 948.3, T1 = 49.27, T2 = 40.57, Heater Set to 0.0
# N = 701, Time = 949.7, T1 = 48.95, T2 = 40.57, Heater Set to 0.0
# N = 702, Time = 951.0, T1 = 48.95, T2 = 40.57, Heater Set to 0.0
# N = 703, Time = 952.3, T1 = 48.62, T2 = 40.57, Heater Set to 0.0
# N = 704, Time = 953.7, T1 = 48.3, T2 = 40.24, Heater Set to 0.0
# N = 705, Time = 955.0, T1 = 48.3, T2 = 40.24, Heater Set to 0.0
# N = 706, Time = 956.3, T1 = 48.3, T2 = 40.24, Heater Set to 0.0
# N = 707, Time = 957.6, T1 = 47.98, T2 = 40.24, Heater Set to 0.0
# N = 708, Time = 959.0, T1 = 47.98, T2 = 40.24, Heater Set to 0.0
# N = 709, Time = 960.3, T1 = 47.66, T2 = 40.24, Heater Set to 0.0
# N = 710, Time = 961.6, T1 = 47.33, T2 = 39.92, Heater Set to 0.0
# N = 711, Time = 963.0, T1 = 47.33, T2 = 39.92, Heater Set to 0.0
# N = 712, Time = 964.3, T1 = 47.01, T2 = 39.92, Heater Set to 0.0
# N = 713, Time = 965.6, T1 = 46.69, T2 = 39.92, Heater Set to 0.0
# N = 714, Time = 966.9, T1 = 46.69, T2 = 39.6, Heater Set to 0.0
# N = 715, Time = 968.3, T1 = 46.37, T2 = 39.6, Heater Set to 0.0
# N = 716, Time = 969.6, T1 = 46.37, T2 = 39.6, Heater Set to 0.0
# N = 717, Time = 970.9, T1 = 46.37, T2 = 39.6, Heater Set to 0.0
# N = 718, Time = 972.2, T1 = 46.05, T2 = 39.6, Heater Set to 0.0
# N = 719, Time = 973.6, T1 = 45.72, T2 = 39.6, Heater Set to 0.0
# N = 720, Time = 974.9, T1 = 45.72, T2 = 39.28, Heater Set to 0.0
# N = 721, Time = 976.2, T1 = 45.72, T2 = 39.28, Heater Set to 0.0
# N = 722, Time = 977.5, T1 = 45.4, T2 = 39.28, Heater Set to 0.0
# N = 723, Time = 978.9, T1 = 45.4, T2 = 39.28, Heater Set to 0.0
# N = 724, Time = 980.2, T1 = 45.08, T2 = 39.28, Heater Set to 0.0
# N = 725, Time = 981.5, T1 = 44.76, T2 = 38.95, Heater Set to 0.0
# N = 726, Time = 982.9, T1 = 44.76, T2 = 38.95, Heater Set to 0.0
# N = 727, Time = 984.2, T1 = 44.76, T2 = 38.95, Heater Set to 0.0
# N = 728, Time = 985.5, T1 = 44.43, T2 = 38.95, Heater Set to 0.0
# N = 729, Time = 986.8, T1 = 44.11, T2 = 38.95, Heater Set to 0.0
# N = 730, Time = 988.2, T1 = 44.11, T2 = 38.31, Heater Set to 0.0
# N = 731, Time = 989.5, T1 = 44.11, T2 = 38.63, Heater Set to 0.0
# N = 732, Time = 990.8, T1 = 43.79, T2 = 38.63, Heater Set to 0.0
# ...
# N = 1263, Time = 1703.9, T1 = 47.33, T2 = 36.38, Heater Set to 0.0
# N = 1264, Time = 1705.3, T1 = 47.33, T2 = 36.38, Heater Set to 0.0
# N = 1265, Time = 1706.6, T1 = 47.01, T2 = 36.7, Heater Set to 0.0
# N = 1266, Time = 1707.9, T1 = 46.69, T2 = 36.38, Heater Set to 0.0
# N = 1267, Time = 1709.3, T1 = 46.69, T2 = 36.38, Heater Set to 0.0
# N = 1268, Time = 1710.6, T1 = 46.37, T2 = 36.38, Heater Set to 0.0
# N = 1269, Time = 1711.9, T1 = 46.37, T2 = 36.38, Heater Set to 0.0
# N = 1270, Time = 1713.2, T1 = 46.37, T2 = 36.38, Heater Set to 0.0
# N = 1271, Time = 1714.6, T1 = 46.05, T2 = 36.38, Heater Set to 0.0
# N = 1272, Time = 1715.9, T1 = 46.05, T2 = 36.38, Heater Set to 0.0
# N = 1273, Time = 1717.2, T1 = 45.72, T2 = 36.38, Heater Set to 0.0
# N = 1274, Time = 1718.5, T1 = 45.72, T2 = 36.38, Heater Set to 0.0
# N = 1275, Time = 1719.9, T1 = 45.4, T2 = 36.38, Heater Set to 0.0
# N = 1276, Time = 1721.2, T1 = 45.08, T2 = 36.38, Heater Set to 0.0
# N = 1277, Time = 1722.5, T1 = 45.08, T2 = 36.05, Heater Set to 0.0
# N = 1278, Time = 1723.8, T1 = 44.76, T2 = 36.38, Heater Set to 0.0
# N = 1279, Time = 1725.2, T1 = 44.76, T2 = 36.05, Heater Set to 0.0
# N = 1280, Time = 1726.5, T1 = 44.76, T2 = 35.73, Heater Set to 0.0
# N = 1281, Time = 1727.8, T1 = 44.43, T2 = 36.05, Heater Set to 0.0
# N = 1282, Time = 1729.1, T1 = 44.43, T2 = 36.05, Heater Set to 0.0
# N = 1283, Time = 1730.4, T1 = 44.43, T2 = 36.05, Heater Set to 0.0
# N = 1284, Time = 1731.8, T1 = 44.11, T2 = 36.05, Heater Set to 0.0
# N = 1285, Time = 1733.1, T1 = 44.11, T2 = 36.05, Heater Set to 0.0
# N = 1286, Time = 1734.4, T1 = 43.79, T2 = 36.05, Heater Set to 0.0
# N = 1287, Time = 1735.7, T1 = 43.79, T2 = 36.05, Heater Set to 0.0
# N = 1288, Time = 1737.1, T1 = 43.47, T2 = 36.05, Heater Set to 0.0
# N = 1289, Time = 1738.4, T1 = 43.47, T2 = 35.73, Heater Set to 0.0
# N = 1290, Time = 1739.7, T1 = 43.47, T2 = 36.05, Heater Set to 0.0
# N = 1291, Time = 1741.0, T1 = 43.14, T2 = 36.05, Heater Set to 0.0
# N = 1292, Time = 1742.4, T1 = 43.14, T2 = 35.73, Heater Set to 0.0
# N = 1293, Time = 1743.7, T1 = 42.82, T2 = 35.73, Heater Set to 0.0
# N = 1294, Time = 1745.0, T1 = 42.82, T2 = 35.73, Heater Set to 0.0
# N = 1295, Time = 1746.3, T1 = 42.5, T2 = 35.73, Heater Set to 0.0
# N = 1296, Time = 1747.7, T1 = 42.5, T2 = 35.73, Heater Set to 0.0
# N = 1297, Time = 1749.0, T1 = 42.18, T2 = 35.73, Heater Set to 0.0
# N = 1298, Time = 1750.3, T1 = 42.18, T2 = 35.09, Heater Set to 0.0
# N = 1299, Time = 1751.7, T1 = 41.86, T2 = 35.73, Heater Set to 0.0
# N = 1300, Time = 1753.0, T1 = 41.86, T2 = 35.73, Heater Set to 0.0
# N = 1301, Time = 1754.3, T1 = 41.86, T2 = 35.41, Heater Set to 0.0
# N = 1302, Time = 1755.6, T1 = 41.53, T2 = 35.41, Heater Set to 0.0
# N = 1303, Time = 1757.0, T1 = 41.53, T2 = 35.41, Heater Set to 0.0
# N = 1304, Time = 1758.3, T1 = 41.53, T2 = 35.41, Heater Set to 0.0
# N = 1305, Time = 1759.6, T1 = 41.21, T2 = 35.41, Heater Set to 0.0
# N = 1306, Time = 1761.0, T1 = 41.21, T2 = 35.41, Heater Set to 0.0
# N = 1307, Time = 1762.3, T1 = 40.89, T2 = 35.41, Heater Set to 0.0
# N = 1308, Time = 1763.6, T1 = 40.89, T2 = 35.41, Heater Set to 0.0
# N = 1309, Time = 1765.0, T1 = 40.57, T2 = 35.09, Heater Set to 0.0
# N = 1310, Time = 1766.3, T1 = 40.57, T2 = 35.41, Heater Set to 0.0
# N = 1311, Time = 1767.6, T1 = 40.57, T2 = 35.09, Heater Set to 0.0
# N = 1312, Time = 1768.9, T1 = 40.24, T2 = 35.09, Heater Set to 0.0
# N = 1313, Time = 1770.3, T1 = 40.24, T2 = 35.09, Heater Set to 0.0
# N = 1314, Time = 1771.6, T1 = 40.24, T2 = 35.09, Heater Set to 0.0
# N = 1315, Time = 1772.9, T1 = 39.92, T2 = 35.09, Heater Set to 0.0
# N = 1316, Time = 1774.2, T1 = 39.92, T2 = 35.09, Heater Set to 0.0
# N = 1317, Time = 1775.5, T1 = 39.92, T2 = 35.09, Heater Set to 0.0
# N = 1318, Time = 1776.9, T1 = 39.92, T2 = 34.76, Heater Set to 0.0
# N = 1319, Time = 1778.2, T1 = 39.6, T2 = 35.09, Heater Set to 0.0
# N = 1320, Time = 1779.5, T1 = 39.6, T2 = 34.76, Heater Set to 0.0
# N = 1321, Time = 1780.8, T1 = 39.28, T2 = 34.76, Heater Set to 0.0
# N = 1322, Time = 1782.2, T1 = 39.28, T2 = 34.76, Heater Set to 0.0
# N = 1323, Time = 1783.5, T1 = 39.28, T2 = 34.76, Heater Set to 0.0
# N = 1324, Time = 1784.8, T1 = 38.95, T2 = 34.76, Heater Set to 0.0
# N = 1325, Time = 1786.1, T1 = 38.95, T2 = 34.76, Heater Set to 0.0
# N = 1326, Time = 1787.5, T1 = 38.95, T2 = 34.76, Heater Set to 0.0
# N = 1327, Time = 1788.8, T1 = 38.63, T2 = 34.76, Heater Set to 0.0
# N = 1328, Time = 1790.1, T1 = 38.63, T2 = 34.76, Heater Set to 0.0
# N = 1329, Time = 1791.4, T1 = 38.63, T2 = 34.44, Heater Set to 0.0
# N = 1330, Time = 1792.8, T1 = 38.63, T2 = 34.44, Heater Set to 0.0
# N = 1331, Time = 1794.1, T1 = 38.31, T2 = 34.44, Heater Set to 0.0
# N = 1332, Time = 1795.4, T1 = 38.31, T2 = 34.44, Heater Set to 0.0
# N = 1333, Time = 1796.7, T1 = 37.99, T2 = 34.44, Heater Set to 0.0
# N = 1334, Time = 1798.1, T1 = 37.99, T2 = 34.44, Heater Set to 0.0
# N = 1335, Time = 1799.4, T1 = 37.99, T2 = 34.44, Heater Set to 0.0
# N = 1336, Time = 1800.7, T1 = 37.99, T2 = 34.12, Heater Set to 0.0
# N = 1337, Time = 1802.1, T1 = 37.67, T2 = 34.12, Heater Set to 0.0
# N = 1338, Time = 1803.4, T1 = 37.67, T2 = 34.12, Heater Set to 0.0
# N = 1339, Time = 1804.7, T1 = 37.67, T2 = 34.12, Heater Set to 0.0
# N = 1340, Time = 1806.0, T1 = 37.67, T2 = 34.12, Heater Set to 0.0
# N = 1341, Time = 1807.4, T1 = 37.34, T2 = 34.12, Heater Set to 0.0
# N = 1342, Time = 1808.7, T1 = 37.34, T2 = 34.12, Heater Set to 0.0
# N = 1343, Time = 1810.0, T1 = 37.02, T2 = 34.12, Heater Set to 0.0
# N = 1344, Time = 1811.4, T1 = 37.02, T2 = 33.8, Heater Set to 0.0
# N = 1345, Time = 1812.7, T1 = 37.02, T2 = 33.8, Heater Set to 0.0
# N = 1346, Time = 1814.0, T1 = 37.02, T2 = 33.8, Heater Set to 0.0
# N = 1347, Time = 1815.3, T1 = 36.7, T2 = 33.8, Heater Set to 0.0
# N = 1348, Time = 1816.7, T1 = 36.7, T2 = 33.8, Heater Set to 0.0
# N = 1349, Time = 1818.0, T1 = 36.7, T2 = 33.8, Heater Set to 0.0
# N = 1350, Time = 1819.3, T1 = 36.7, T2 = 33.8, Heater Set to 0.0
# N = 1351, Time = 1820.7, T1 = 36.7, T2 = 33.8, Heater Set to 0.0
# N = 1352, Time = 1822.0, T1 = 36.38, T2 = 33.48, Heater Set to 0.0
# N = 1353, Time = 1823.3, T1 = 36.38, T2 = 33.8, Heater Set to 0.0
# N = 1354, Time = 1824.6, T1 = 36.38, T2 = 33.48, Heater Set to 0.0
# N = 1355, Time = 1825.9, T1 = 36.38, T2 = 33.48, Heater Set to 0.0
# N = 1356, Time = 1827.3, T1 = 36.05, T2 = 33.48, Heater Set to 0.0
# N = 1357, Time = 1828.6, T1 = 36.05, T2 = 33.48, Heater Set to 0.0
# N = 1358, Time = 1829.9, T1 = 36.05, T2 = 33.48, Heater Set to 0.0
# N = 1359, Time = 1831.3, T1 = 35.73, T2 = 33.48, Heater Set to 0.0
# N = 1360, Time = 1832.6, T1 = 35.73, T2 = 33.48, Heater Set to 0.0
# N = 1361, Time = 1833.9, T1 = 35.73, T2 = 33.48, Heater Set to 0.0
# N = 1362, Time = 1835.2, T1 = 35.73, T2 = 33.15, Heater Set to 0.0
# N = 1363, Time = 1836.6, T1 = 35.73, T2 = 33.48, Heater Set to 0.0
# N = 1364, Time = 1837.9, T1 = 35.41, T2 = 32.83, Heater Set to 0.0
# N = 1365, Time = 1839.2, T1 = 35.41, T2 = 32.83, Heater Set to 0.0
# N = 1366, Time = 1840.5, T1 = 35.41, T2 = 33.15, Heater Set to 0.0
# N = 1367, Time = 1841.9, T1 = 35.41, T2 = 33.15, Heater Set to 0.0
# N = 1368, Time = 1843.2, T1 = 35.41, T2 = 33.15, Heater Set to 0.0
# N = 1369, Time = 1844.5, T1 = 35.09, T2 = 33.15, Heater Set to 0.0
# N = 1370, Time = 1845.8, T1 = 35.09, T2 = 33.15, Heater Set to 0.0
# N = 1371, Time = 1847.2, T1 = 34.76, T2 = 33.15, Heater Set to 0.0
# N = 1372, Time = 1848.5, T1 = 35.09, T2 = 32.83, Heater Set to 0.0
# N = 1373, Time = 1849.8, T1 = 34.44, T2 = 32.83, Heater Set to 0.0
# N = 1374, Time = 1851.2, T1 = 34.76, T2 = 32.83, Heater Set to 0.0
# N = 1375, Time = 1852.5, T1 = 34.76, T2 = 32.83, Heater Set to 0.0
# N = 1376, Time = 1853.8, T1 = 34.76, T2 = 32.83, Heater Set to 0.0
# N = 1377, Time = 1855.1, T1 = 34.76, T2 = 32.83, Heater Set to 0.0
# N = 1378, Time = 1856.5, T1 = 34.44, T2 = 32.83, Heater Set to 0.0
# N = 1379, Time = 1857.8, T1 = 34.44, T2 = 32.51, Heater Set to 0.0
# N = 1380, Time = 1859.1, T1 = 34.44, T2 = 32.51, Heater Set to 0.0
# N = 1381, Time = 1860.5, T1 = 34.12, T2 = 32.51, Heater Set to 0.0
# N = 1382, Time = 1861.8, T1 = 34.12, T2 = 32.51, Heater Set to 0.0
# N = 1383, Time = 1863.1, T1 = 34.12, T2 = 32.51, Heater Set to 0.0
# N = 1384, Time = 1864.4, T1 = 34.12, T2 = 32.51, Heater Set to 0.0
# N = 1385, Time = 1865.8, T1 = 34.12, T2 = 32.51, Heater Set to 0.0
# N = 1386, Time = 1867.1, T1 = 34.12, T2 = 32.51, Heater Set to 0.0
# N = 1387, Time = 1868.4, T1 = 33.8, T2 = 32.51, Heater Set to 0.0
# N = 1388, Time = 1869.7, T1 = 33.8, T2 = 32.51, Heater Set to 0.0
# N = 1389, Time = 1871.1, T1 = 33.8, T2 = 32.19, Heater Set to 0.0
# N = 1390, Time = 1872.4, T1 = 33.8, T2 = 32.19, Heater Set to 0.0
# N = 1391, Time = 1873.7, T1 = 33.48, T2 = 32.19, Heater Set to 0.0
# N = 1392, Time = 1875.0, T1 = 33.48, T2 = 32.19, Heater Set to 0.0
# N = 1393, Time = 1876.4, T1 = 33.48, T2 = 32.19, Heater Set to 0.0
# N = 1394, Time = 1877.7, T1 = 33.48, T2 = 32.19, Heater Set to 0.0
# N = 1395, Time = 1879.0, T1 = 33.48, T2 = 32.19, Heater Set to 0.0
# N = 1396, Time = 1880.3, T1 = 33.48, T2 = 31.86, Heater Set to 0.0
# N = 1397, Time = 1881.7, T1 = 33.15, T2 = 31.86, Heater Set to 0.0
# N = 1398, Time = 1883.0, T1 = 33.15, T2 = 31.86, Heater Set to 0.0
# N = 1399, Time = 1884.3, T1 = 33.15, T2 = 31.86, Heater Set to 0.0
# N = 1400, Time = 1885.7, T1 = 33.15, T2 = 31.86, Heater Set to 0.0
# N = 1401, Time = 1887.0, T1 = 33.15, T2 = 31.86, Heater Set to 0.0
# N = 1402, Time = 1888.3, T1 = 32.83, T2 = 31.86, Heater Set to 0.0
# N = 1403, Time = 1889.6, T1 = 33.15, T2 = 31.86, Heater Set to 0.0
# N = 1404, Time = 1891.0, T1 = 32.83, T2 = 31.86, Heater Set to 0.0
# N = 1405, Time = 1892.3, T1 = 32.83, T2 = 31.86, Heater Set to 0.0
# N = 1406, Time = 1893.6, T1 = 32.83, T2 = 31.86, Heater Set to 0.0
# N = 1407, Time = 1894.9, T1 = 32.83, T2 = 31.54, Heater Set to 0.0
# N = 1408, Time = 1896.2, T1 = 32.51, T2 = 31.54, Heater Set to 0.0
# N = 1409, Time = 1897.6, T1 = 32.51, T2 = 31.54, Heater Set to 0.0
# N = 1410, Time = 1898.9, T1 = 32.51, T2 = 31.54, Heater Set to 0.0
# N = 1411, Time = 1900.2, T1 = 32.51, T2 = 31.54, Heater Set to 0.0
# N = 1412, Time = 1901.5, T1 = 32.51, T2 = 31.54, Heater Set to 0.0
# N = 1413, Time = 1902.9, T1 = 32.51, T2 = 31.54, Heater Set to 0.0
# N = 1414, Time = 1904.2, T1 = 32.51, T2 = 31.54, Heater Set to 0.0
# N = 1415, Time = 1905.5, T1 = 32.19, T2 = 31.22, Heater Set to 0.0
# N = 1416, Time = 1906.8, T1 = 32.19, T2 = 31.22, Heater Set to 0.0
# N = 1417, Time = 1908.1, T1 = 32.19, T2 = 31.22, Heater Set to 0.0
# N = 1418, Time = 1909.5, T1 = 32.19, T2 = 31.22, Heater Set to 0.0
# N = 1419, Time = 1910.8, T1 = 32.19, T2 = 31.22, Heater Set to 0.0
# N = 1420, Time = 1912.1, T1 = 32.19, T2 = 31.22, Heater Set to 0.0
# N = 1421, Time = 1913.4, T1 = 31.86, T2 = 31.22, Heater Set to 0.0
# N = 1422, Time = 1914.8, T1 = 31.86, T2 = 31.22, Heater Set to 0.0
# N = 1423, Time = 1916.1, T1 = 31.86, T2 = 31.22, Heater Set to 0.0
# N = 1424, Time = 1917.4, T1 = 31.86, T2 = 31.22, Heater Set to 0.0
# N = 1425, Time = 1918.7, T1 = 31.86, T2 = 31.22, Heater Set to 0.0
# N = 1426, Time = 1920.0, T1 = 31.86, T2 = 30.9, Heater Set to 0.0
# N = 1427, Time = 1921.4, T1 = 31.86, T2 = 30.9, Heater Set to 0.0
# N = 1428, Time = 1922.7, T1 = 31.54, T2 = 30.9, Heater Set to 0.0
# N = 1429, Time = 1924.0, T1 = 31.54, T2 = 30.9, Heater Set to 0.0
# N = 1430, Time = 1925.3, T1 = 31.54, T2 = 30.9, Heater Set to 0.0
# N = 1431, Time = 1926.7, T1 = 31.54, T2 = 30.9, Heater Set to 0.0
# N = 1432, Time = 1928.0, T1 = 31.54, T2 = 30.9, Heater Set to 0.0
# N = 1433, Time = 1929.3, T1 = 31.54, T2 = 30.9, Heater Set to 0.0
# N = 1434, Time = 1930.6, T1 = 31.22, T2 = 30.9, Heater Set to 0.0
# N = 1435, Time = 1932.0, T1 = 31.22, T2 = 30.57, Heater Set to 0.0
# N = 1436, Time = 1933.3, T1 = 31.22, T2 = 30.57, Heater Set to 0.0
# N = 1437, Time = 1934.6, T1 = 31.22, T2 = 30.57, Heater Set to 0.0
# N = 1438, Time = 1935.9, T1 = 31.22, T2 = 30.57, Heater Set to 0.0
# N = 1439, Time = 1937.3, T1 = 31.22, T2 = 30.57, Heater Set to 0.0
# N = 1440, Time = 1938.6, T1 = 31.22, T2 = 30.57, Heater Set to 0.0
# N = 1441, Time = 1939.9, T1 = 31.22, T2 = 30.57, Heater Set to 0.0
# N = 1442, Time = 1941.3, T1 = 31.22, T2 = 30.57, Heater Set to 0.0
# N = 1443, Time = 1942.6, T1 = 30.9, T2 = 30.57, Heater Set to 0.0
# N = 1444, Time = 1943.9, T1 = 30.9, T2 = 30.57, Heater Set to 0.0
# N = 1445, Time = 1945.2, T1 = 30.9, T2 = 30.25, Heater Set to 0.0
# N = 1446, Time = 1946.6, T1 = 30.9, T2 = 30.57, Heater Set to 0.0
# N = 1447, Time = 1947.9, T1 = 30.9, T2 = 30.25, Heater Set to 0.0
# N = 1448, Time = 1949.2, T1 = 30.9, T2 = 30.25, Heater Set to 0.0
# N = 1449, Time = 1950.5, T1 = 30.9, T2 = 30.25, Heater Set to 0.0
# N = 1450, Time = 1951.8, T1 = 30.9, T2 = 30.25, Heater Set to 0.0
# N = 1451, Time = 1953.2, T1 = 30.9, T2 = 30.25, Heater Set to 0.0
# N = 1452, Time = 1954.5, T1 = 30.9, T2 = 30.25, Heater Set to 0.0
# N = 1453, Time = 1955.8, T1 = 30.57, T2 = 30.25, Heater Set to 0.0
# N = 1454, Time = 1957.1, T1 = 29.93, T2 = 30.25, Heater Set to 0.0
# N = 1455, Time = 1958.5, T1 = 30.57, T2 = 30.25, Heater Set to 0.0
# N = 1456, Time = 1959.8, T1 = 30.57, T2 = 30.25, Heater Set to 0.0
# N = 1457, Time = 1961.1, T1 = 30.57, T2 = 29.93, Heater Set to 0.0
# N = 1458, Time = 1962.5, T1 = 30.57, T2 = 29.93, Heater Set to 0.0
# N = 1459, Time = 1963.8, T1 = 30.57, T2 = 30.25, Heater Set to 0.0
# N = 1460, Time = 1965.1, T1 = 30.57, T2 = 29.93, Heater Set to 0.0
# N = 1461, Time = 1966.4, T1 = 30.57, T2 = 29.93, Heater Set to 0.0
# N = 1462, Time = 1967.8, T1 = 30.25, T2 = 29.93, Heater Set to 0.0
# N = 1463, Time = 1969.1, T1 = 30.25, T2 = 29.93, Heater Set to 0.0
# N = 1464, Time = 1970.4, T1 = 30.25, T2 = 29.93, Heater Set to 0.0
# N = 1465, Time = 1971.7, T1 = 30.25, T2 = 29.93, Heater Set to 0.0
# N = 1466, Time = 1973.1, T1 = 30.25, T2 = 29.61, Heater Set to 0.0
# N = 1467, Time = 1974.4, T1 = 30.25, T2 = 29.93, Heater Set to 0.0
# N = 1468, Time = 1975.7, T1 = 30.25, T2 = 29.93, Heater Set to 0.0
# N = 1469, Time = 1977.0, T1 = 30.25, T2 = 29.93, Heater Set to 0.0
# N = 1470, Time = 1978.4, T1 = 30.25, T2 = 29.61, Heater Set to 0.0
# N = 1471, Time = 1979.7, T1 = 29.93, T2 = 29.61, Heater Set to 0.0
# N = 1472, Time = 1981.0, T1 = 29.29, T2 = 29.61, Heater Set to 0.0
# N = 1473, Time = 1982.3, T1 = 29.93, T2 = 29.61, Heater Set to 0.0
# N = 1474, Time = 1983.7, T1 = 29.93, T2 = 29.61, Heater Set to 0.0
# N = 1475, Time = 1985.0, T1 = 29.93, T2 = 29.61, Heater Set to 0.0
# N = 1476, Time = 1986.3, T1 = 29.93, T2 = 29.61, Heater Set to 0.0
# N = 1477, Time = 1987.6, T1 = 29.93, T2 = 29.61, Heater Set to 0.0
# N = 1478, Time = 1989.0, T1 = 29.93, T2 = 29.61, Heater Set to 0.0
# N = 1479, Time = 1990.3, T1 = 29.93, T2 = 29.61, Heater Set to 0.0
# N = 1480, Time = 1991.6, T1 = 29.93, T2 = 29.61, Heater Set to 0.0
# N = 1481, Time = 1993.0, T1 = 29.61, T2 = 29.61, Heater Set to 0.0
# N = 1482, Time = 1994.3, T1 = 29.93, T2 = 29.61, Heater Set to 0.0
# N = 1483, Time = 1995.6, T1 = 29.61, T2 = 29.61, Heater Set to 0.0
# N = 1484, Time = 1996.9, T1 = 29.61, T2 = 29.29, Heater Set to 0.0
# N = 1485, Time = 1998.2, T1 = 29.61, T2 = 29.29, Heater Set to 0.0
# N = 1486, Time = 1999.6, T1 = 29.61, T2 = 29.29, Heater Set to 0.0
# N = 1487, Time = 2000.9, T1 = 29.61, T2 = 29.29, Heater Set to 0.0
# N = 1488, Time = 2002.2, T1 = 29.61, T2 = 29.29, Heater Set to 0.0
# N = 1489, Time = 2003.6, T1 = 29.61, T2 = 29.29, Heater Set to 0.0
# N = 1490, Time = 2004.9, T1 = 29.61, T2 = 29.29, Heater Set to 0.0
# N = 1491, Time = 2006.2, T1 = 29.61, T2 = 29.29, Heater Set to 0.0
# N = 1492, Time = 2007.5, T1 = 29.61, T2 = 29.29, Heater Set to 0.0
# N = 1493, Time = 2008.9, T1 = 29.29, T2 = 29.29, Heater Set to 0.0
# N = 1494, Time = 2010.2, T1 = 29.29, T2 = 29.29, Heater Set to 0.0
# N = 1495, Time = 2011.5, T1 = 29.29, T2 = 29.29, Heater Set to 0.0
# N = 1496, Time = 2012.8, T1 = 29.29, T2 = 28.96, Heater Set to 0.0
# N = 1497, Time = 2014.2, T1 = 29.29, T2 = 28.96, Heater Set to 0.0
# N = 1498, Time = 2015.5, T1 = 29.29, T2 = 28.96, Heater Set to 0.0
# N = 1499, Time = 2016.8, T1 = 29.29, T2 = 28.96, Heater Set to 0.0
# N = 1500, Time = 2018.1, T1 = 29.29, T2 = 28.96, Heater Set to 0.0
# TCLab disconnected successfully.

# %%
if (0): # Grab the current temperature from the TCLab if desired. (I.e. = 1)
    import tclab
    lab = tclab.TCLab()
    print('T1 = {0}, T2 = {1}'.format(lab.T1, lab.T2))
    print('T1 = {0}, T2 = {1}'.format(lab.T1, lab.T2))
    print('T1 = {0}, T2 = {1}'.format(lab.T1, lab.T2))
    lab.close()

# %%
#lab.close()
