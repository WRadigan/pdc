# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
from pytexit import py2tex
from IPython.display import Markdown
from gekko import GEKKO
import pandas as pd
from matplotlib import rcParams
import os
import sys
from copy import copy


# %matplotlib widget
#%matplotlib inline

# Look for custom python codes in the Radigan Engineering Vault...
sys.path.insert(1, 'C:\\\\RadiganVault\\\\Python')

import RadiganEngineeringDefaults as RE
from RadiganEngineering_Materials_Library import *
from RadiganEngineeringTorsionSpring import *
from RadiganEngineeringBellevilleSpring import *

# Use higher quality figures in PDF exports
#rcParams['figure.dpi']= 300
#rcParams['figure.figsize'] = [8, 6]
set_matplotlib_formats('png', 'pdf')

print(ALUMINUM_6061_T6.Specific_Heat)
# Out:
# 896 joule / kelvin / kilogram

# %%
# https://apmonitor.com/pdc/index.php/Main/TCLabSim
# https://apmonitor.com/pdc/index.php/Main/TCLabConvection

# Update model with natural convection estimation.

TCLab = GEKKO()    # create GEKKO model for dx/dt

t_sim = 360 * ureg.sec # Number of seconds to simulate
points_per_second = 1 # Only works if this is the same as the 'sampling frequency' in the cell below...

TCLab.time = np.linspace(0, t_sim.magnitude, (t_sim.magnitude * points_per_second) + 1) * ureg.sec # time points

# dt is in the units of ________.

T_Ambient = 26.0 # degC
HS_Mass  = 0.004 * ureg.kg 
HS_Cp    = 500.0 * (ureg.joule /  (ureg.kg    * ureg.kelvin)) # Heatsink Specific Heat
HS_Conv  = 10.0  * (ureg.watt) / ((ureg.m**2) * ureg.kelvin)  # Convection coefficient
HS_Area  = 0.0012 * ureg.m**2                                 # Heatsink Surface Area

# Starting temperature for the heatsink.
# Might be equal to 'T_Ambient' or something else.
#HS_T_Start = T_Ambient
HS_T_Start = 28.0


HeaterValues = np.zeros(len(TCLab.time))
HeaterValues[15:75] = 50
#HeaterValues[0:9] = 50
Heater_Q  = TCLab.Param(HeaterValues)  # "Percentage of maximum value" of the heater -- set the heater percentage down below 

K_p       = TCLab.Param()  # ~= 0.01 Watts / % # This seems a little low, I would have expected more than 1 Watt at full power [100%]
HS_Temp     = TCLab.Var(HS_T_Start) # GEKKO variable for the temperature of the heatsink

TCLab.Equation(HS_Temp.dt()  == ( (HS_Conv.to('watt/(m^2*K)').magnitude * HS_Area.to('m^2').magnitude) * (T_Ambient - HS_Temp) + (K_p * Heater_Q) ) / 
                                    (HS_Mass.to('kg').magnitude * HS_Cp.to('joule/(kg*K)').magnitude) )

# solve ODEs and plot
# https://gekko.readthedocs.io/en/latest/imode.html
TCLab.options.IMODE = 4 # dynamic simulation

# Type: Integer, Input/Output
# Default Value: 0
# Description: Cold start model: 0=warm start, 1=cold start, 2=decompose problem
#TCLab.options.COLDSTART = 2

#TCLab.options.SOLVER = 1
#TCLab.options.MAX_ITER = 1000

#---------------------
TCLab.options.NODES = 6
#---------------------

TCLab.options.TIME_SHIFT=0


fig = plt.figure()
plt_ax = plt.axes(label='TCLab')
plt_ax.set_ylim(25,45)

#HeaterValue = 50
#Heater_Q.value = HeaterValue # Turn the heater on to the specified percentage value
#print(Heater_Q.value)

#k_vals = [10, 20, 30, 50]
# Solve the dynamic problem for this set of Kp values.
K_p_vals = [0.008, 0.01]

for K_p_val in K_p_vals:
    K_p.value = K_p_val
    TCLab.solve(disp=False)
    plt_ax.plot(TCLab.time,HS_Temp, marker='',linewidth=1,label='K_p = {0}'.format(K_p.value[0]))


######################################################################################
# Create the 'dummy' plot with NaN's that will be replaced with measured data below.
T1 = np.empty(len(TCLab.time))
T1[:] = np.nan
T1_time = np.empty(len(TCLab.time))
T1_time[:] = np.nan
MeasuredData, = plt_ax.plot(T1_time,T1,'r.', label='Measured')
######################################################################################

plt.grid(True)
plt.title('TC Lab Thermal Simulation')
plt.xlabel('Time (sec)')
plt.ylabel('Temperature (degC)')
plt.legend()
plt.show()

# instantiate a second axes that shares the same x-axis and plot the Heater Input
Q_ax = plt_ax.twinx()  
Q_ax.plot(TCLab.time,Heater_Q, color = 'gray', linestyle = ':', marker='',linewidth=2,label='Heater')
Q_ax.set_ylim(-5,105)
plt.ylabel('Heater Percentage')
plt.legend(loc = 'lower right')

# Now solve as a steady-state problem in case the simulation time isn't long enough.
# Sometimes the parameter values doen't seem to 'stick'...
#TCLab.options.IMODE = 3
#TCLab.solve(disp=False)
#print('Final Temperature = {0} for a Heater Value of {1}% and a K_p of {2}'.format(HS_Temp.value[0], HeaterValue, K_p.value[0]))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# C:\ProgramData\Anaconda3\lib\site-packages\gekko\gk_write_files.py:144: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   csv_data = np.hstack(('time',np.array(self.time).flatten().astype(object)))
# C:\ProgramData\Anaconda3\lib\site-packages\gekko\gk_write_files.py:144: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   csv_data = np.hstack(('time',np.array(self.time).flatten().astype(object)))

# %%
# Actual measured data
import tclab
import time

if (1):
    lab = tclab.TCLab()
    #T1 = [lab.T1] # Old-style list based plotting...
    
    # Static On / Off Heater control
    #lab.Q1(50)
    #print('Turning Heater on to {0}%'.format(HeaterValue))
    #lab.Q1(HeaterValue)
    
    # Use the array defined above to set the heater.
    lab.Q1(HeaterValues[0])

    T1[:] = np.nan       # Reset the measured temperatures to NaN's
    T1_time[:] = np.nan

    for i in range(len(TCLab.time)):
        time.sleep(1)
        lab.Q1(HeaterValues[i])
        #print(lab.T1)
        print('Time = {3} sec, T1 = {0}, T2 = {1}, Heater Set to {2}'.format(lab.T1, lab.T2, HeaterValues[i], i))
        T1[i] = lab.T1
        T1_time[i] = i
        MeasuredData.set_ydata(np.array(T1))
        MeasuredData.set_xdata(np.array(T1_time))
        plt_ax.set_title("{0} of {1} Points Measured".format(i+1,t_sim))
        fig.canvas.draw()
        fig.canvas.flush_events()
        plt.show()

    lab.close()
    plt.show()
# Out:
# TCLab version 0.4.9
# Arduino Leonardo connected on port COM3 at 115200 baud.
# TCLab Firmware 1.4.3 Arduino Leonardo/Micro.
# Time = 0 sec, T1 = 28.0, T2 = 27.67, Heater Set to 0.0
# Time = 1 sec, T1 = 28.0, T2 = 27.67, Heater Set to 0.0
# Time = 2 sec, T1 = 28.0, T2 = 27.67, Heater Set to 0.0
# Time = 3 sec, T1 = 28.0, T2 = 27.67, Heater Set to 0.0
# Time = 4 sec, T1 = 28.0, T2 = 27.67, Heater Set to 0.0
# Time = 5 sec, T1 = 28.0, T2 = 27.67, Heater Set to 0.0
# Time = 6 sec, T1 = 28.0, T2 = 27.67, Heater Set to 0.0
# Time = 7 sec, T1 = 28.0, T2 = 27.67, Heater Set to 0.0
# Time = 8 sec, T1 = 28.0, T2 = 27.67, Heater Set to 0.0
# Time = 9 sec, T1 = 28.0, T2 = 27.67, Heater Set to 0.0
# Time = 10 sec, T1 = 28.0, T2 = 27.67, Heater Set to 0.0
# Time = 11 sec, T1 = 28.0, T2 = 27.67, Heater Set to 0.0
# Time = 12 sec, T1 = 28.0, T2 = 27.67, Heater Set to 0.0
# Time = 13 sec, T1 = 28.0, T2 = 27.67, Heater Set to 0.0
# Time = 14 sec, T1 = 28.0, T2 = 27.67, Heater Set to 0.0
# Time = 15 sec, T1 = 28.0, T2 = 27.67, Heater Set to 50.0
# Time = 16 sec, T1 = 28.0, T2 = 27.67, Heater Set to 50.0
# Time = 17 sec, T1 = 28.0, T2 = 27.67, Heater Set to 50.0
# Time = 18 sec, T1 = 28.0, T2 = 27.67, Heater Set to 50.0
# Time = 19 sec, T1 = 28.0, T2 = 27.67, Heater Set to 50.0
# Time = 20 sec, T1 = 28.0, T2 = 27.67, Heater Set to 50.0
# Time = 21 sec, T1 = 28.0, T2 = 27.67, Heater Set to 50.0
# Time = 22 sec, T1 = 28.0, T2 = 27.67, Heater Set to 50.0
# Time = 23 sec, T1 = 28.32, T2 = 27.67, Heater Set to 50.0
# Time = 24 sec, T1 = 28.32, T2 = 27.67, Heater Set to 50.0
# Time = 25 sec, T1 = 28.32, T2 = 27.67, Heater Set to 50.0
# Time = 26 sec, T1 = 28.64, T2 = 27.67, Heater Set to 50.0
# Time = 27 sec, T1 = 28.64, T2 = 27.67, Heater Set to 50.0
# Time = 28 sec, T1 = 28.64, T2 = 27.67, Heater Set to 50.0
# Time = 29 sec, T1 = 28.96, T2 = 27.67, Heater Set to 50.0
# Time = 30 sec, T1 = 28.96, T2 = 27.67, Heater Set to 50.0
# Time = 31 sec, T1 = 28.96, T2 = 27.67, Heater Set to 50.0
# Time = 32 sec, T1 = 28.96, T2 = 27.67, Heater Set to 50.0
# Time = 33 sec, T1 = 29.29, T2 = 27.67, Heater Set to 50.0
# Time = 34 sec, T1 = 29.61, T2 = 27.67, Heater Set to 50.0
# Time = 35 sec, T1 = 29.61, T2 = 27.67, Heater Set to 50.0
# Time = 36 sec, T1 = 29.93, T2 = 27.67, Heater Set to 50.0
# Time = 37 sec, T1 = 29.93, T2 = 27.67, Heater Set to 50.0
# Time = 38 sec, T1 = 30.25, T2 = 27.67, Heater Set to 50.0
# Time = 39 sec, T1 = 30.25, T2 = 27.67, Heater Set to 50.0
# Time = 40 sec, T1 = 30.57, T2 = 27.67, Heater Set to 50.0
# Time = 41 sec, T1 = 30.57, T2 = 27.67, Heater Set to 50.0
# Time = 42 sec, T1 = 30.9, T2 = 27.67, Heater Set to 50.0
# Time = 43 sec, T1 = 30.9, T2 = 27.67, Heater Set to 50.0
# Time = 44 sec, T1 = 31.22, T2 = 27.67, Heater Set to 50.0
# Time = 45 sec, T1 = 31.54, T2 = 28.0, Heater Set to 50.0
# Time = 46 sec, T1 = 31.54, T2 = 28.0, Heater Set to 50.0
# Time = 47 sec, T1 = 31.86, T2 = 27.67, Heater Set to 50.0
# Time = 48 sec, T1 = 31.86, T2 = 28.0, Heater Set to 50.0
# Time = 49 sec, T1 = 32.19, T2 = 28.0, Heater Set to 50.0
# Time = 50 sec, T1 = 32.51, T2 = 28.0, Heater Set to 50.0
# Time = 51 sec, T1 = 32.51, T2 = 28.0, Heater Set to 50.0
# Time = 52 sec, T1 = 32.83, T2 = 28.0, Heater Set to 50.0
# Time = 53 sec, T1 = 32.83, T2 = 28.0, Heater Set to 50.0
# Time = 54 sec, T1 = 33.15, T2 = 28.0, Heater Set to 50.0
# Time = 55 sec, T1 = 33.15, T2 = 28.0, Heater Set to 50.0
# Time = 56 sec, T1 = 33.48, T2 = 28.0, Heater Set to 50.0
# Time = 57 sec, T1 = 33.48, T2 = 28.0, Heater Set to 50.0
# Time = 58 sec, T1 = 33.8, T2 = 28.0, Heater Set to 50.0
# Time = 59 sec, T1 = 34.12, T2 = 28.32, Heater Set to 50.0
# Time = 60 sec, T1 = 34.44, T2 = 28.32, Heater Set to 50.0
# Time = 61 sec, T1 = 34.44, T2 = 28.32, Heater Set to 50.0
# Time = 62 sec, T1 = 34.76, T2 = 28.0, Heater Set to 50.0
# Time = 63 sec, T1 = 34.76, T2 = 28.32, Heater Set to 50.0
# Time = 64 sec, T1 = 35.09, T2 = 28.0, Heater Set to 50.0
# Time = 65 sec, T1 = 35.41, T2 = 28.32, Heater Set to 50.0
# Time = 66 sec, T1 = 35.41, T2 = 28.32, Heater Set to 50.0
# Time = 67 sec, T1 = 35.73, T2 = 28.32, Heater Set to 50.0
# Time = 68 sec, T1 = 35.73, T2 = 28.32, Heater Set to 50.0
# Time = 69 sec, T1 = 36.05, T2 = 28.32, Heater Set to 50.0
# Time = 70 sec, T1 = 36.05, T2 = 28.32, Heater Set to 50.0
# Time = 71 sec, T1 = 36.38, T2 = 28.64, Heater Set to 50.0
# Time = 72 sec, T1 = 36.7, T2 = 28.32, Heater Set to 50.0
# Time = 73 sec, T1 = 37.02, T2 = 28.32, Heater Set to 50.0
# Time = 74 sec, T1 = 37.02, T2 = 28.64, Heater Set to 50.0
# Time = 75 sec, T1 = 37.02, T2 = 28.64, Heater Set to 0.0
# Time = 76 sec, T1 = 37.34, T2 = 28.64, Heater Set to 0.0
# Time = 77 sec, T1 = 37.67, T2 = 28.64, Heater Set to 0.0
# Time = 78 sec, T1 = 37.67, T2 = 28.64, Heater Set to 0.0
# Time = 79 sec, T1 = 37.99, T2 = 28.64, Heater Set to 0.0
# Time = 80 sec, T1 = 37.99, T2 = 28.96, Heater Set to 0.0
# Time = 81 sec, T1 = 38.31, T2 = 28.64, Heater Set to 0.0
# Time = 82 sec, T1 = 38.31, T2 = 28.96, Heater Set to 0.0
# Time = 83 sec, T1 = 38.63, T2 = 28.96, Heater Set to 0.0
# Time = 84 sec, T1 = 38.63, T2 = 28.96, Heater Set to 0.0
# Time = 85 sec, T1 = 38.63, T2 = 28.96, Heater Set to 0.0
# Time = 86 sec, T1 = 38.95, T2 = 28.96, Heater Set to 0.0
# Time = 87 sec, T1 = 38.95, T2 = 28.96, Heater Set to 0.0
# Time = 88 sec, T1 = 38.95, T2 = 28.96, Heater Set to 0.0
# Time = 89 sec, T1 = 38.95, T2 = 28.96, Heater Set to 0.0
# Time = 90 sec, T1 = 39.28, T2 = 28.96, Heater Set to 0.0
# Time = 91 sec, T1 = 39.28, T2 = 29.29, Heater Set to 0.0
# Time = 92 sec, T1 = 39.28, T2 = 29.29, Heater Set to 0.0
# Time = 93 sec, T1 = 39.28, T2 = 29.29, Heater Set to 0.0
# Time = 94 sec, T1 = 39.28, T2 = 29.29, Heater Set to 0.0
# Time = 95 sec, T1 = 39.28, T2 = 29.29, Heater Set to 0.0
# Time = 96 sec, T1 = 39.28, T2 = 29.29, Heater Set to 0.0
# Time = 97 sec, T1 = 39.28, T2 = 29.29, Heater Set to 0.0
# Time = 98 sec, T1 = 39.28, T2 = 29.29, Heater Set to 0.0
# Time = 99 sec, T1 = 39.28, T2 = 29.29, Heater Set to 0.0
# Time = 100 sec, T1 = 39.28, T2 = 29.29, Heater Set to 0.0
# Time = 101 sec, T1 = 39.28, T2 = 29.61, Heater Set to 0.0
# Time = 102 sec, T1 = 39.28, T2 = 29.61, Heater Set to 0.0
# Time = 103 sec, T1 = 39.28, T2 = 29.61, Heater Set to 0.0
# Time = 104 sec, T1 = 39.28, T2 = 29.61, Heater Set to 0.0
# Time = 105 sec, T1 = 39.28, T2 = 29.61, Heater Set to 0.0
# Time = 106 sec, T1 = 39.28, T2 = 29.61, Heater Set to 0.0
# Time = 107 sec, T1 = 39.28, T2 = 29.61, Heater Set to 0.0
# Time = 108 sec, T1 = 39.28, T2 = 29.61, Heater Set to 0.0
# Time = 109 sec, T1 = 39.28, T2 = 29.93, Heater Set to 0.0
# Time = 110 sec, T1 = 39.28, T2 = 29.93, Heater Set to 0.0
# Time = 111 sec, T1 = 39.28, T2 = 29.93, Heater Set to 0.0
# Time = 112 sec, T1 = 39.28, T2 = 29.93, Heater Set to 0.0
# Time = 113 sec, T1 = 38.95, T2 = 29.93, Heater Set to 0.0
# Time = 114 sec, T1 = 38.95, T2 = 29.93, Heater Set to 0.0
# Time = 115 sec, T1 = 38.95, T2 = 29.93, Heater Set to 0.0
# Time = 116 sec, T1 = 38.95, T2 = 29.93, Heater Set to 0.0
# Time = 117 sec, T1 = 38.95, T2 = 29.93, Heater Set to 0.0
# Time = 118 sec, T1 = 38.95, T2 = 29.93, Heater Set to 0.0
# Time = 119 sec, T1 = 38.95, T2 = 30.25, Heater Set to 0.0
# Time = 120 sec, T1 = 38.63, T2 = 30.25, Heater Set to 0.0
# Time = 121 sec, T1 = 38.63, T2 = 30.25, Heater Set to 0.0
# Time = 122 sec, T1 = 38.63, T2 = 30.25, Heater Set to 0.0
# Time = 123 sec, T1 = 38.63, T2 = 30.25, Heater Set to 0.0
# Time = 124 sec, T1 = 38.63, T2 = 30.25, Heater Set to 0.0
# Time = 125 sec, T1 = 38.31, T2 = 30.25, Heater Set to 0.0
# Time = 126 sec, T1 = 38.31, T2 = 30.25, Heater Set to 0.0
# Time = 127 sec, T1 = 38.31, T2 = 30.25, Heater Set to 0.0
# Time = 128 sec, T1 = 38.31, T2 = 30.25, Heater Set to 0.0
# Time = 129 sec, T1 = 38.31, T2 = 30.25, Heater Set to 0.0
# Time = 130 sec, T1 = 38.31, T2 = 30.57, Heater Set to 0.0
# Time = 131 sec, T1 = 37.99, T2 = 30.57, Heater Set to 0.0
# Time = 132 sec, T1 = 37.99, T2 = 30.25, Heater Set to 0.0
# Time = 133 sec, T1 = 37.99, T2 = 30.57, Heater Set to 0.0
# Time = 134 sec, T1 = 37.99, T2 = 30.57, Heater Set to 0.0
# Time = 135 sec, T1 = 37.99, T2 = 30.57, Heater Set to 0.0
# Time = 136 sec, T1 = 37.67, T2 = 30.57, Heater Set to 0.0
# Time = 137 sec, T1 = 37.99, T2 = 30.57, Heater Set to 0.0
# Time = 138 sec, T1 = 37.67, T2 = 30.57, Heater Set to 0.0
# Time = 139 sec, T1 = 37.67, T2 = 30.57, Heater Set to 0.0
# Time = 140 sec, T1 = 37.67, T2 = 30.57, Heater Set to 0.0
# Time = 141 sec, T1 = 37.67, T2 = 30.57, Heater Set to 0.0
# Time = 142 sec, T1 = 37.34, T2 = 30.57, Heater Set to 0.0
# Time = 143 sec, T1 = 37.34, T2 = 30.57, Heater Set to 0.0
# Time = 144 sec, T1 = 37.34, T2 = 30.57, Heater Set to 0.0
# Time = 145 sec, T1 = 37.34, T2 = 30.57, Heater Set to 0.0
# Time = 146 sec, T1 = 37.34, T2 = 30.57, Heater Set to 0.0
# Time = 147 sec, T1 = 37.02, T2 = 30.57, Heater Set to 0.0
# Time = 148 sec, T1 = 37.02, T2 = 30.57, Heater Set to 0.0
# Time = 149 sec, T1 = 37.02, T2 = 30.57, Heater Set to 0.0
# Time = 150 sec, T1 = 37.02, T2 = 30.57, Heater Set to 0.0
# Time = 151 sec, T1 = 37.02, T2 = 30.9, Heater Set to 0.0
# Time = 152 sec, T1 = 36.7, T2 = 30.57, Heater Set to 0.0
# Time = 153 sec, T1 = 37.02, T2 = 30.9, Heater Set to 0.0
# Time = 154 sec, T1 = 36.7, T2 = 30.9, Heater Set to 0.0
# Time = 155 sec, T1 = 36.38, T2 = 30.9, Heater Set to 0.0
# Time = 156 sec, T1 = 36.38, T2 = 30.9, Heater Set to 0.0
# Time = 157 sec, T1 = 36.38, T2 = 30.9, Heater Set to 0.0
# Time = 158 sec, T1 = 36.38, T2 = 30.9, Heater Set to 0.0
# Time = 159 sec, T1 = 36.38, T2 = 30.9, Heater Set to 0.0
# Time = 160 sec, T1 = 36.05, T2 = 30.57, Heater Set to 0.0
# Time = 161 sec, T1 = 36.05, T2 = 30.57, Heater Set to 0.0
# Time = 162 sec, T1 = 36.05, T2 = 30.57, Heater Set to 0.0
# Time = 163 sec, T1 = 36.05, T2 = 30.57, Heater Set to 0.0
# Time = 164 sec, T1 = 36.05, T2 = 30.57, Heater Set to 0.0
# Time = 165 sec, T1 = 36.05, T2 = 30.57, Heater Set to 0.0
# Time = 166 sec, T1 = 35.73, T2 = 30.57, Heater Set to 0.0
# Time = 167 sec, T1 = 35.73, T2 = 30.57, Heater Set to 0.0
# Time = 168 sec, T1 = 35.73, T2 = 30.57, Heater Set to 0.0
# Time = 169 sec, T1 = 35.73, T2 = 30.9, Heater Set to 0.0
# Time = 170 sec, T1 = 35.73, T2 = 30.9, Heater Set to 0.0
# Time = 171 sec, T1 = 35.41, T2 = 30.9, Heater Set to 0.0
# Time = 172 sec, T1 = 35.41, T2 = 30.57, Heater Set to 0.0
# Time = 173 sec, T1 = 35.41, T2 = 30.57, Heater Set to 0.0
# Time = 174 sec, T1 = 35.41, T2 = 30.57, Heater Set to 0.0
# Time = 175 sec, T1 = 35.41, T2 = 30.57, Heater Set to 0.0
# Time = 176 sec, T1 = 35.41, T2 = 30.57, Heater Set to 0.0
# Time = 177 sec, T1 = 35.41, T2 = 30.57, Heater Set to 0.0
# Time = 178 sec, T1 = 35.09, T2 = 30.57, Heater Set to 0.0
# Time = 179 sec, T1 = 35.09, T2 = 30.9, Heater Set to 0.0
# Time = 180 sec, T1 = 35.09, T2 = 30.57, Heater Set to 0.0
# Time = 181 sec, T1 = 35.09, T2 = 30.57, Heater Set to 0.0
# Time = 182 sec, T1 = 35.09, T2 = 30.57, Heater Set to 0.0
# Time = 183 sec, T1 = 34.76, T2 = 30.57, Heater Set to 0.0
# Time = 184 sec, T1 = 34.76, T2 = 30.57, Heater Set to 0.0
# Time = 185 sec, T1 = 34.76, T2 = 30.57, Heater Set to 0.0
# Time = 186 sec, T1 = 34.76, T2 = 30.57, Heater Set to 0.0
# Time = 187 sec, T1 = 34.76, T2 = 30.57, Heater Set to 0.0
# Time = 188 sec, T1 = 34.76, T2 = 30.9, Heater Set to 0.0
# Time = 189 sec, T1 = 34.76, T2 = 30.57, Heater Set to 0.0
# Time = 190 sec, T1 = 34.44, T2 = 30.9, Heater Set to 0.0
# Time = 191 sec, T1 = 34.44, T2 = 30.57, Heater Set to 0.0
# Time = 192 sec, T1 = 34.44, T2 = 30.9, Heater Set to 0.0
# Time = 193 sec, T1 = 34.44, T2 = 30.57, Heater Set to 0.0
# Time = 194 sec, T1 = 34.44, T2 = 30.9, Heater Set to 0.0
# Time = 195 sec, T1 = 34.44, T2 = 30.9, Heater Set to 0.0
# Time = 196 sec, T1 = 34.44, T2 = 30.57, Heater Set to 0.0
# Time = 197 sec, T1 = 34.44, T2 = 30.57, Heater Set to 0.0
# Time = 198 sec, T1 = 34.44, T2 = 30.57, Heater Set to 0.0
# Time = 199 sec, T1 = 34.44, T2 = 30.57, Heater Set to 0.0
# Time = 200 sec, T1 = 34.44, T2 = 30.9, Heater Set to 0.0
# Time = 201 sec, T1 = 34.44, T2 = 30.57, Heater Set to 0.0
# Time = 202 sec, T1 = 34.12, T2 = 30.57, Heater Set to 0.0
# Time = 203 sec, T1 = 34.12, T2 = 30.57, Heater Set to 0.0
# Time = 204 sec, T1 = 34.12, T2 = 30.57, Heater Set to 0.0
# Time = 205 sec, T1 = 34.12, T2 = 30.57, Heater Set to 0.0
# Time = 206 sec, T1 = 33.8, T2 = 30.57, Heater Set to 0.0
# Time = 207 sec, T1 = 34.12, T2 = 30.57, Heater Set to 0.0
# Time = 208 sec, T1 = 34.12, T2 = 30.57, Heater Set to 0.0
# Time = 209 sec, T1 = 33.8, T2 = 30.57, Heater Set to 0.0
# Time = 210 sec, T1 = 33.8, T2 = 30.57, Heater Set to 0.0
# Time = 211 sec, T1 = 33.8, T2 = 30.57, Heater Set to 0.0
# Time = 212 sec, T1 = 33.8, T2 = 30.57, Heater Set to 0.0
# Time = 213 sec, T1 = 33.8, T2 = 30.57, Heater Set to 0.0
# Time = 214 sec, T1 = 33.8, T2 = 30.57, Heater Set to 0.0
# Time = 215 sec, T1 = 33.8, T2 = 30.57, Heater Set to 0.0
# Time = 216 sec, T1 = 33.48, T2 = 30.57, Heater Set to 0.0
# Time = 217 sec, T1 = 33.48, T2 = 30.57, Heater Set to 0.0
# Time = 218 sec, T1 = 33.48, T2 = 30.57, Heater Set to 0.0
# Time = 219 sec, T1 = 33.8, T2 = 30.57, Heater Set to 0.0
# Time = 220 sec, T1 = 33.48, T2 = 30.57, Heater Set to 0.0
# Time = 221 sec, T1 = 33.48, T2 = 30.57, Heater Set to 0.0
# Time = 222 sec, T1 = 33.48, T2 = 30.57, Heater Set to 0.0
# Time = 223 sec, T1 = 33.48, T2 = 30.57, Heater Set to 0.0
# Time = 224 sec, T1 = 33.48, T2 = 30.57, Heater Set to 0.0
# Time = 225 sec, T1 = 33.48, T2 = 30.57, Heater Set to 0.0
# Time = 226 sec, T1 = 33.48, T2 = 30.57, Heater Set to 0.0
# Time = 227 sec, T1 = 33.15, T2 = 30.57, Heater Set to 0.0
# Time = 228 sec, T1 = 33.15, T2 = 30.57, Heater Set to 0.0
# Time = 229 sec, T1 = 33.15, T2 = 30.57, Heater Set to 0.0
# Time = 230 sec, T1 = 33.15, T2 = 30.57, Heater Set to 0.0
# Time = 231 sec, T1 = 33.15, T2 = 30.57, Heater Set to 0.0
# Time = 232 sec, T1 = 33.15, T2 = 30.57, Heater Set to 0.0
# Time = 233 sec, T1 = 33.15, T2 = 30.57, Heater Set to 0.0
# Time = 234 sec, T1 = 33.15, T2 = 30.57, Heater Set to 0.0
# Time = 235 sec, T1 = 33.15, T2 = 30.57, Heater Set to 0.0
# Time = 236 sec, T1 = 33.15, T2 = 30.57, Heater Set to 0.0
# Time = 237 sec, T1 = 32.83, T2 = 30.57, Heater Set to 0.0
# Time = 238 sec, T1 = 32.83, T2 = 30.57, Heater Set to 0.0
# Time = 239 sec, T1 = 32.83, T2 = 30.57, Heater Set to 0.0
# Time = 240 sec, T1 = 32.83, T2 = 30.57, Heater Set to 0.0
# Time = 241 sec, T1 = 32.83, T2 = 30.57, Heater Set to 0.0
# Time = 242 sec, T1 = 32.83, T2 = 30.57, Heater Set to 0.0
# Time = 243 sec, T1 = 32.83, T2 = 30.57, Heater Set to 0.0
# Time = 244 sec, T1 = 32.83, T2 = 30.57, Heater Set to 0.0
# Time = 245 sec, T1 = 32.51, T2 = 30.57, Heater Set to 0.0
# Time = 246 sec, T1 = 32.83, T2 = 30.57, Heater Set to 0.0
# Time = 247 sec, T1 = 32.51, T2 = 30.57, Heater Set to 0.0
# Time = 248 sec, T1 = 32.51, T2 = 30.57, Heater Set to 0.0
# Time = 249 sec, T1 = 32.83, T2 = 30.57, Heater Set to 0.0
# Time = 250 sec, T1 = 32.83, T2 = 30.57, Heater Set to 0.0
# Time = 251 sec, T1 = 32.51, T2 = 30.57, Heater Set to 0.0
# Time = 252 sec, T1 = 32.51, T2 = 30.57, Heater Set to 0.0
# Time = 253 sec, T1 = 32.51, T2 = 30.57, Heater Set to 0.0
# Time = 254 sec, T1 = 32.51, T2 = 30.57, Heater Set to 0.0
# Time = 255 sec, T1 = 32.51, T2 = 30.57, Heater Set to 0.0
# Time = 256 sec, T1 = 32.51, T2 = 30.57, Heater Set to 0.0
# Time = 257 sec, T1 = 32.51, T2 = 30.57, Heater Set to 0.0
# Time = 258 sec, T1 = 32.51, T2 = 30.57, Heater Set to 0.0
# Time = 259 sec, T1 = 32.51, T2 = 30.57, Heater Set to 0.0
# Time = 260 sec, T1 = 32.51, T2 = 30.57, Heater Set to 0.0
# Time = 261 sec, T1 = 32.51, T2 = 30.25, Heater Set to 0.0
# Time = 262 sec, T1 = 32.19, T2 = 30.57, Heater Set to 0.0
# Time = 263 sec, T1 = 32.19, T2 = 30.25, Heater Set to 0.0
# Time = 264 sec, T1 = 32.19, T2 = 30.25, Heater Set to 0.0
# Time = 265 sec, T1 = 32.19, T2 = 30.25, Heater Set to 0.0
# Time = 266 sec, T1 = 32.19, T2 = 30.25, Heater Set to 0.0
# Time = 267 sec, T1 = 32.19, T2 = 30.25, Heater Set to 0.0
# Time = 268 sec, T1 = 32.19, T2 = 30.25, Heater Set to 0.0
# Time = 269 sec, T1 = 32.19, T2 = 30.25, Heater Set to 0.0
# Time = 270 sec, T1 = 32.19, T2 = 30.25, Heater Set to 0.0
# Time = 271 sec, T1 = 31.86, T2 = 30.25, Heater Set to 0.0
# Time = 272 sec, T1 = 31.86, T2 = 30.25, Heater Set to 0.0
# Time = 273 sec, T1 = 31.86, T2 = 30.25, Heater Set to 0.0
# Time = 274 sec, T1 = 31.86, T2 = 30.25, Heater Set to 0.0
# Time = 275 sec, T1 = 31.86, T2 = 30.25, Heater Set to 0.0
# Time = 276 sec, T1 = 31.86, T2 = 30.25, Heater Set to 0.0
# Time = 277 sec, T1 = 31.86, T2 = 30.25, Heater Set to 0.0
# Time = 278 sec, T1 = 31.86, T2 = 30.25, Heater Set to 0.0
# Time = 279 sec, T1 = 31.86, T2 = 30.25, Heater Set to 0.0
# Time = 280 sec, T1 = 31.86, T2 = 30.25, Heater Set to 0.0
# Time = 281 sec, T1 = 31.86, T2 = 30.25, Heater Set to 0.0
# Time = 282 sec, T1 = 31.86, T2 = 30.25, Heater Set to 0.0
# Time = 283 sec, T1 = 31.86, T2 = 30.25, Heater Set to 0.0
# Time = 284 sec, T1 = 31.86, T2 = 30.25, Heater Set to 0.0
# Time = 285 sec, T1 = 31.86, T2 = 30.25, Heater Set to 0.0
# Time = 286 sec, T1 = 31.86, T2 = 30.25, Heater Set to 0.0
# Time = 287 sec, T1 = 31.54, T2 = 30.25, Heater Set to 0.0
# Time = 288 sec, T1 = 31.54, T2 = 30.25, Heater Set to 0.0
# Time = 289 sec, T1 = 31.54, T2 = 30.25, Heater Set to 0.0
# Time = 290 sec, T1 = 31.54, T2 = 30.25, Heater Set to 0.0
# Time = 291 sec, T1 = 31.54, T2 = 30.25, Heater Set to 0.0
# Time = 292 sec, T1 = 31.54, T2 = 30.25, Heater Set to 0.0
# Time = 293 sec, T1 = 31.54, T2 = 30.25, Heater Set to 0.0
# Time = 294 sec, T1 = 31.54, T2 = 30.25, Heater Set to 0.0
# Time = 295 sec, T1 = 31.54, T2 = 30.25, Heater Set to 0.0
# Time = 296 sec, T1 = 31.54, T2 = 30.25, Heater Set to 0.0
# Time = 297 sec, T1 = 31.54, T2 = 30.25, Heater Set to 0.0
# Time = 298 sec, T1 = 31.22, T2 = 30.25, Heater Set to 0.0
# Time = 299 sec, T1 = 31.54, T2 = 30.25, Heater Set to 0.0
# Time = 300 sec, T1 = 31.22, T2 = 30.25, Heater Set to 0.0
# Time = 301 sec, T1 = 31.54, T2 = 30.25, Heater Set to 0.0
# Time = 302 sec, T1 = 31.54, T2 = 30.25, Heater Set to 0.0
# Time = 303 sec, T1 = 31.22, T2 = 30.25, Heater Set to 0.0
# Time = 304 sec, T1 = 31.22, T2 = 30.25, Heater Set to 0.0
# Time = 305 sec, T1 = 31.22, T2 = 30.25, Heater Set to 0.0
# Time = 306 sec, T1 = 31.22, T2 = 30.25, Heater Set to 0.0
# Time = 307 sec, T1 = 31.22, T2 = 29.93, Heater Set to 0.0
# Time = 308 sec, T1 = 31.22, T2 = 29.93, Heater Set to 0.0
# Time = 309 sec, T1 = 31.22, T2 = 30.25, Heater Set to 0.0
# Time = 310 sec, T1 = 31.22, T2 = 30.25, Heater Set to 0.0
# Time = 311 sec, T1 = 31.22, T2 = 29.93, Heater Set to 0.0
# Time = 312 sec, T1 = 31.22, T2 = 29.93, Heater Set to 0.0
# Time = 313 sec, T1 = 31.22, T2 = 29.93, Heater Set to 0.0
# Time = 314 sec, T1 = 31.22, T2 = 29.93, Heater Set to 0.0
# Time = 315 sec, T1 = 31.22, T2 = 29.93, Heater Set to 0.0
# Time = 316 sec, T1 = 31.22, T2 = 29.93, Heater Set to 0.0
# Time = 317 sec, T1 = 30.9, T2 = 29.93, Heater Set to 0.0
# Time = 318 sec, T1 = 30.9, T2 = 29.93, Heater Set to 0.0
# Time = 319 sec, T1 = 31.22, T2 = 29.93, Heater Set to 0.0
# Time = 320 sec, T1 = 31.22, T2 = 29.93, Heater Set to 0.0
# Time = 321 sec, T1 = 30.9, T2 = 29.93, Heater Set to 0.0
# Time = 322 sec, T1 = 30.9, T2 = 29.93, Heater Set to 0.0
# Time = 323 sec, T1 = 30.9, T2 = 29.93, Heater Set to 0.0
# Time = 324 sec, T1 = 30.9, T2 = 29.93, Heater Set to 0.0
# Time = 325 sec, T1 = 30.9, T2 = 29.93, Heater Set to 0.0
# Time = 326 sec, T1 = 30.9, T2 = 29.93, Heater Set to 0.0
# Time = 327 sec, T1 = 30.9, T2 = 29.93, Heater Set to 0.0
# Time = 328 sec, T1 = 30.9, T2 = 29.93, Heater Set to 0.0
# Time = 329 sec, T1 = 30.9, T2 = 29.93, Heater Set to 0.0
# Time = 330 sec, T1 = 30.9, T2 = 29.93, Heater Set to 0.0
# Time = 331 sec, T1 = 30.9, T2 = 29.93, Heater Set to 0.0
# Time = 332 sec, T1 = 30.9, T2 = 29.93, Heater Set to 0.0
# Time = 333 sec, T1 = 30.9, T2 = 29.93, Heater Set to 0.0
# Time = 334 sec, T1 = 30.9, T2 = 29.93, Heater Set to 0.0
# Time = 335 sec, T1 = 30.9, T2 = 29.93, Heater Set to 0.0
# Time = 336 sec, T1 = 30.9, T2 = 29.93, Heater Set to 0.0
# Time = 337 sec, T1 = 30.9, T2 = 29.93, Heater Set to 0.0
# Time = 338 sec, T1 = 30.9, T2 = 29.93, Heater Set to 0.0
# Time = 339 sec, T1 = 30.9, T2 = 29.93, Heater Set to 0.0
# Time = 340 sec, T1 = 30.9, T2 = 29.93, Heater Set to 0.0
# Time = 341 sec, T1 = 30.57, T2 = 29.61, Heater Set to 0.0
# Time = 342 sec, T1 = 30.57, T2 = 29.93, Heater Set to 0.0
# Time = 343 sec, T1 = 30.57, T2 = 29.93, Heater Set to 0.0
# Time = 344 sec, T1 = 30.57, T2 = 29.93, Heater Set to 0.0
# Time = 345 sec, T1 = 30.57, T2 = 29.93, Heater Set to 0.0
# Time = 346 sec, T1 = 30.57, T2 = 29.61, Heater Set to 0.0
# Time = 347 sec, T1 = 30.25, T2 = 29.61, Heater Set to 0.0
# Time = 348 sec, T1 = 30.57, T2 = 29.61, Heater Set to 0.0
# Time = 349 sec, T1 = 30.57, T2 = 29.61, Heater Set to 0.0
# Time = 350 sec, T1 = 30.57, T2 = 29.61, Heater Set to 0.0
# Time = 351 sec, T1 = 30.57, T2 = 29.61, Heater Set to 0.0
# Time = 352 sec, T1 = 30.57, T2 = 29.61, Heater Set to 0.0
# Time = 353 sec, T1 = 30.57, T2 = 29.61, Heater Set to 0.0
# Time = 354 sec, T1 = 30.57, T2 = 29.61, Heater Set to 0.0
# Time = 355 sec, T1 = 30.57, T2 = 29.61, Heater Set to 0.0
# Time = 356 sec, T1 = 30.57, T2 = 29.61, Heater Set to 0.0
# Time = 357 sec, T1 = 30.57, T2 = 29.61, Heater Set to 0.0
# Time = 358 sec, T1 = 30.57, T2 = 29.61, Heater Set to 0.0
# Time = 359 sec, T1 = 30.57, T2 = 29.61, Heater Set to 0.0
# Time = 360 sec, T1 = 30.57, T2 = 29.61, Heater Set to 0.0
# TCLab disconnected successfully.

# %%
if (1): # Grab the current temperature from the TCLab if desired. (I.e. = 1)
    import tclab
    lab = tclab.TCLab()
    print('T1 = {0}, T2 = {1}'.format(lab.T1, lab.T2))
    print('T1 = {0}, T2 = {1}'.format(lab.T1, lab.T2))
    print('T1 = {0}, T2 = {1}'.format(lab.T1, lab.T2))
    lab.close()
# Out:
# TCLab version 0.4.9
# Arduino Leonardo connected on port COM3 at 115200 baud.
# TCLab Firmware 1.4.3 Arduino Leonardo/Micro.
# T1 = 28.0, T2 = 27.67
# T1 = 28.0, T2 = 27.67
# T1 = 28.0, T2 = 27.67
# TCLab disconnected successfully.

# %%
#lab.close()
# Out:
# TCLab disconnected successfully.
